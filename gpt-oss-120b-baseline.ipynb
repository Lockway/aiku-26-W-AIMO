# %%
# %pip uninstall --yes 'keras' 'matplotlib' 'scikit-learn' 'tensorflow'
# Out:
# Found existing installation: keras 3.10.0
# Uninstalling keras-3.10.0:
#   Successfully uninstalled keras-3.10.0
# Found existing installation: matplotlib 3.10.0
# Uninstalling matplotlib-3.10.0:
#   Successfully uninstalled matplotlib-3.10.0
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings; warnings.simplefilter('ignore')
import os, sys, subprocess, gc, re, math, time, queue, threading, contextlib

# %%
def set_env(archive, tmp):
    if not os.path.exists(tmp):
        os.makedirs(tmp, exist_ok=True)
        subprocess.run(['tar', '-xzf', archive, '-C', tmp], check=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '--no-index', '--find-links', f'{tmp}/wheels', 
                    'unsloth', 'trl', 'vllm', 'openai_harmony'], check=True)

set_env('/kaggle/input/aimo-3-utils/wheels.tar.gz', '/kaggle/tmp/setup')
# Out:
# Looking in links: /kaggle/tmp/setup/wheels
# Processing /kaggle/tmp/setup/wheels/unsloth-2025.12.9-py3-none-any.whl
# Processing /kaggle/tmp/setup/wheels/trl-0.24.0-py3-none-any.whl
# Processing /kaggle/tmp/setup/wheels/vllm-0.11.2-cp38-abi3-manylinux1_x86_64.whl
# Processing /kaggle/tmp/setup/wheels/openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Processing /kaggle/tmp/setup/wheels/unsloth_zoo-2025.12.7-py3-none-any.whl (from unsloth)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (25.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.23.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.9.5)
# Processing /kaggle/tmp/setup/wheels/tyro-1.0.3-py3-none-any.whl (from unsloth)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.29.5)
# Processing /kaggle/tmp/setup/wheels/xformers-0.0.33.post1-cp39-abi3-manylinux_2_28_x86_64.whl (from unsloth)
# Processing /kaggle/tmp/setup/wheels/bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (from unsloth)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.4.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.2.1)
# Processing /kaggle/tmp/setup/wheels/datasets-4.3.0-py3-none-any.whl (from unsloth)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.11.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.17.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.36.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.35.2)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3 in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.57.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from vllm) (2025.11.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm) (5.5.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.32.5)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.0.8)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm) (9.0.0)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.22.1)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.119.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from vllm) (3.13.2)
# Requirement already satisfied: openai>=1.99.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.109.1)
# Requirement already satisfied: pydantic>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.12.5)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.23.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm) (11.3.0)
# Processing /kaggle/tmp/setup/wheels/prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (from vllm)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.12.0)
# Processing /kaggle/tmp/setup/wheels/lm_format_enforcer-0.11.3-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/diskcache-5.6.3-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/lark-1.2.2-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/xgrammar-0.1.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.15.0)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (3.20.1)
# Processing /kaggle/tmp/setup/wheels/partial_json_parser-0.2.1.1.post7-py3-none-any.whl (from vllm)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (26.2.1)
# Processing /kaggle/tmp/setup/wheels/msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/gguf-0.17.1-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/mistral_common-1.8.8-py3-none-any.whl (from mistral_common[image]>=1.8.5->vllm)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.12.0.88)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from vllm) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.17.0)
# Processing /kaggle/tmp/setup/wheels/setuptools-80.9.0-py3-none-any.whl (from vllm)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm) (0.8.1)
# Processing /kaggle/tmp/setup/wheels/compressed_tensors-0.12.2-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/depyf-0.20.0-py3-none-any.whl (from vllm)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm) (3.1.1)
# Processing /kaggle/tmp/setup/wheels/watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm) (4.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from vllm) (1.15.3)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from vllm) (1.13.0)
# Processing /kaggle/tmp/setup/wheels/pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/cbor2-5.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/anthropic-0.71.0-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/model_hosting_container_standards-0.1.12-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from vllm)
# Requirement already satisfied: ray>=2.48.0 in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm) (2.52.1)
# Processing /kaggle/tmp/setup/wheels/torch-2.9.0+cu128-cp312-cp312-manylinux_2_28_x86_64.whl (from unsloth)
# Processing /kaggle/tmp/setup/wheels/torchaudio-2.9.0+cu128-cp312-cp312-manylinux_2_28_x86_64.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/torchvision-0.24.0+cu128-cp312-cp312-manylinux_2_28_x86_64.whl (from unsloth)
# Processing /kaggle/tmp/setup/wheels/flashinfer_python-0.5.2-py3-none-any.whl (from vllm)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic==0.71.0->vllm) (1.3.1)
# Processing /kaggle/tmp/setup/wheels/loguru-0.7.3-py3-none-any.whl (from compressed-tensors==0.12.2->vllm)
# Processing /kaggle/tmp/setup/wheels/astor-0.8.1-py2.py3-none-any.whl (from depyf==0.20.0->vllm)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.20.0->vllm) (0.4.0)
# Processing /kaggle/tmp/setup/wheels/apache_tvm_ffi-0.1.7-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from flashinfer-python==0.5.2->vllm)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.5.2->vllm) (8.3.1)
# Processing /kaggle/tmp/setup/wheels/nvidia_cudnn_frontend-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from flashinfer-python==0.5.2->vllm)
# Processing /kaggle/tmp/setup/wheels/nvidia_cutlass_dsl-4.3.4-cp312-cp312-manylinux_2_28_x86_64.whl (from flashinfer-python==0.5.2->vllm)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.5.2->vllm) (12.575.51)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.5.2->vllm) (0.9.0)
# Processing /kaggle/tmp/setup/wheels/interegular-0.3.3-py37-none-any.whl (from lm-format-enforcer==0.11.3->vllm)
# Processing /kaggle/tmp/setup/wheels/llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from numba==0.61.2->vllm)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (2025.10.0)
# Processing /kaggle/tmp/setup/wheels/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (9.10.2.21)
# Processing /kaggle/tmp/setup/wheels/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (0.7.1)
# Processing /kaggle/tmp/setup/wheels/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from torch>=2.4.0->unsloth)
# Processing /kaggle/tmp/setup/wheels/triton-3.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from unsloth)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth) (0.6.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (22.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.6.0)
# Processing /kaggle/tmp/setup/wheels/multiprocess-0.70.16-py312-none-any.whl (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth)
# Processing /kaggle/tmp/setup/wheels/fsspec-2025.9.0-py3-none-any.whl (from torch>=2.4.0->unsloth)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.48.0)
# Processing /kaggle/tmp/setup/wheels/fastapi_cli-0.0.20-py3-none-any.whl (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.3.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.38.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.2.1rc0)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm) (4.25.1)
# Processing /kaggle/tmp/setup/wheels/pydantic_extra_types-2.10.6-py3-none-any.whl (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm)
# Requirement already satisfied: jmespath in /usr/local/lib/python3.12/dist-packages (from model-hosting-container-standards<1.0.0->vllm) (1.0.1)
# INFO: pip is looking at multiple versions of model-hosting-container-standards to determine which version is compatible with other requirements. This could take a while.
# Processing /kaggle/tmp/setup/wheels/fastapi-0.128.0-py3-none-any.whl (from vllm)
# Processing /kaggle/tmp/setup/wheels/annotated_doc-0.0.4-py3-none-any.whl (from fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.11.0)
# Processing /kaggle/tmp/setup/wheels/starlette-0.50.0-py3-none-any.whl (from fastapi[standard]>=0.115.0->vllm)
# Processing /kaggle/tmp/setup/wheels/supervisor-4.3.0-py2.py3-none-any.whl (from model-hosting-container-standards<1.0.0->vllm)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm) (0.4.2)
# INFO: pip is looking at multiple versions of ray to determine which version is compatible with other requirements. This could take a while.
# Processing /kaggle/tmp/setup/wheels/ray-2.53.0-cp312-cp312-manylinux2014_x86_64.whl (from ray[cgraph]>=2.48.0->vllm)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm) (1.1.2)
# INFO: pip is looking at multiple versions of ray[cgraph] to determine which version is compatible with other requirements. This could take a while.
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm) (13.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2025.11.12)
# Processing /kaggle/tmp/setup/wheels/torchao-0.15.0+cu128-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from unsloth_zoo>=2025.12.7->unsloth)
# Processing /kaggle/tmp/setup/wheels/cut_cross_entropy-25.1.1-py3-none-any.whl (from unsloth_zoo>=2025.12.7->unsloth)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.22.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth) (8.7.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (4.4.4)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm) (2.8.0)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.20.0)
# Processing /kaggle/tmp/setup/wheels/rich_toolkit-0.17.1-py3-none-any.whl (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Processing /kaggle/tmp/setup/wheels/fastapi_cloud_cli-0.8.0-py3-none-any.whl (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic==0.71.0->vllm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic==0.71.0->vllm) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm) (0.27.1)
# Processing /kaggle/tmp/setup/wheels/cuda_python-13.1.1-py3-none-any.whl (from nvidia-cutlass-dsl>=4.2.1->flashinfer-python==0.5.2->vllm)
# Processing /kaggle/tmp/setup/wheels/pycountry-24.6.1-py3-none-any.whl (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->fastapi[standard]>=0.115.0->vllm) (1.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Processing /kaggle/tmp/setup/wheels/httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Processing /kaggle/tmp/setup/wheels/uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm) (0.8.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.3)
# Processing /kaggle/tmp/setup/wheels/cuda_bindings-13.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from cuda-python>=12.8->nvidia-cutlass-dsl>=4.2.1->flashinfer-python==0.5.2->vllm)
# Processing /kaggle/tmp/setup/wheels/cuda_pathfinder-1.3.3-py3-none-any.whl (from cuda-python>=12.8->nvidia-cutlass-dsl>=4.2.1->flashinfer-python==0.5.2->vllm)
# Processing /kaggle/tmp/setup/wheels/rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.42.1)
# Processing /kaggle/tmp/setup/wheels/fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (14.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.1.2)
# Installing collected packages: torchao, supervisor, uvloop, triton, setuptools, setproctitle, rignore, pycountry, pybase64, partial-json-parser, outlines_core, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cudnn-frontend, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, multiprocess, msgspec, loguru, llvmlite, llguidance, lark, interegular, httptools, gguf, fsspec, fastar, diskcache, cuda-pathfinder, cbor2, astor, apache-tvm-ffi, annotated-doc, watchfiles, tyro, starlette, nvidia-cusparse-cu12, nvidia-cufft-cu12, numba, depyf, cuda-bindings, rich-toolkit, pydantic-extra-types, prometheus-fastapi-instrumentator, openai_harmony, nvidia-cusolver-cu12, lm-format-enforcer, fastapi, cuda-python, anthropic, torch, ray, nvidia-cutlass-dsl, model-hosting-container-standards, fastapi-cloud-cli, fastapi-cli, datasets, xgrammar, xformers, torchvision, torchaudio, mistral_common, flashinfer-python, cut_cross_entropy, compressed-tensors, bitsandbytes, trl, unsloth_zoo, vllm, unsloth
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvshmem-cu12
#     Found existing installation: nvidia-nvshmem-cu12 3.4.5
#     Uninstalling nvidia-nvshmem-cu12-3.4.5:
#       Successfully uninstalled nvidia-nvshmem-cu12-3.4.5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.11.1.6
#     Uninstalling nvidia-cufile-cu12-1.11.1.6:
#       Successfully uninstalled nvidia-cufile-cu12-1.11.1.6
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.18
#     Uninstalling multiprocess-0.70.18:
#       Successfully uninstalled multiprocess-0.70.18
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lark
#     Found existing installation: lark 1.3.0
#     Uninstalling lark-1.3.0:
#       Successfully uninstalled lark-1.3.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.10.0
#     Uninstalling fsspec-2025.10.0:
#       Successfully uninstalled fsspec-2025.10.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.48.0
#     Uninstalling starlette-0.48.0:
#       Successfully uninstalled starlette-0.48.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.119.1
#     Uninstalling fastapi-0.119.1:
#       Successfully uninstalled fastapi-0.119.1
#   Attempting uninstall: cuda-python
#     Found existing installation: cuda-python 12.6.2.post1
#     Uninstalling cuda-python-12.6.2.post1:
#       Successfully uninstalled cuda-python-12.6.2.post1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: ray
#     Found existing installation: ray 2.52.1
#     Uninstalling ray-2.52.1:
#       Successfully uninstalled ray-2.52.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.4.1
#     Uninstalling datasets-4.4.1:
#       Successfully uninstalled datasets-4.4.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0+cu126
#     Uninstalling torchvision-0.23.0+cu126:
#       Successfully uninstalled torchvision-0.23.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.8.0+cu126
#     Uninstalling torchaudio-2.8.0+cu126:
#       Successfully uninstalled torchaudio-2.8.0+cu126
# Successfully installed annotated-doc-0.0.4 anthropic-0.71.0 apache-tvm-ffi-0.1.7 astor-0.8.1 bitsandbytes-0.49.0 cbor2-5.7.1 compressed-tensors-0.12.2 cuda-bindings-13.1.1 cuda-pathfinder-1.3.3 cuda-python-13.1.1 cut_cross_entropy-25.1.1 datasets-4.3.0 depyf-0.20.0 diskcache-5.6.3 fastapi-0.128.0 fastapi-cli-0.0.20 fastapi-cloud-cli-0.8.0 fastar-0.8.0 flashinfer-python-0.5.2 fsspec-2025.9.0 gguf-0.17.1 httptools-0.7.1 interegular-0.3.3 lark-1.2.2 llguidance-1.3.0 llvmlite-0.44.0 lm-format-enforcer-0.11.3 loguru-0.7.3 mistral_common-1.8.8 model-hosting-container-standards-0.1.12 msgspec-0.20.0 multiprocess-0.70.16 numba-0.61.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-frontend-1.17.0 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cutlass-dsl-4.3.4 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 openai_harmony-0.0.8 outlines_core-0.2.11 partial-json-parser-0.2.1.1.post7 prometheus-fastapi-instrumentator-7.1.0 pybase64-1.4.3 pycountry-24.6.1 pydantic-extra-types-2.10.6 ray-2.53.0 rich-toolkit-0.17.1 rignore-0.7.6 setproctitle-1.3.7 setuptools-80.9.0 starlette-0.50.0 supervisor-4.3.0 torch-2.9.0+cu128 torchao-0.15.0+cu128 torchaudio-2.9.0+cu128 torchvision-0.24.0+cu128 triton-3.5.0 trl-0.24.0 tyro-1.0.3 unsloth-2025.12.9 unsloth_zoo-2025.12.7 uvloop-0.22.1 vllm-0.11.2 watchfiles-1.1.1 xformers-0.0.33.post1 xgrammar-0.1.25
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kauldron 1.3.0 requires scikit-learn, which is not installed.
# kauldron 1.3.0 requires tensorflow, which is not installed.
# ydata-profiling 4.18.0 requires matplotlib<=3.10,>=3.5, which is not installed.
# pyldavis 3.4.1 requires scikit-learn>=1.0.0, which is not installed.
# stable-baselines3 2.1.0 requires matplotlib, which is not installed.
# sentence-transformers 5.1.1 requires scikit-learn, which is not installed.
# librosa 0.11.0 requires scikit-learn>=1.1.0, which is not installed.
# cuml-cu12 25.6.0 requires scikit-learn>=1.5, which is not installed.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# bigframes 2.26.0 requires matplotlib>=3.7.1, which is not installed.
# arviz 0.22.0 requires matplotlib>=3.8, which is not installed.
# pynndescent 0.5.13 requires scikit-learn>=0.18, which is not installed.
# shap 0.49.1 requires scikit-learn, which is not installed.
# fastai 2.8.4 requires matplotlib, which is not installed.
# fastai 2.8.4 requires scikit-learn, which is not installed.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, which is not installed.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.2.19 which is incompatible.
# cudf-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# cuml-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# pylibraft-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# cuvs-cu12 25.6.1 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# fastai 2.8.4 requires torch<2.9,>=1.10, but you have torch 2.9.0+cu128 which is incompatible.
# rmm-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# pylibcudf-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 13.1.1 which is incompatible.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.

# %%
subprocess.run(['ls', '/kaggle/tmp/setup/tiktoken_encodings'])
# Out:
# cl100k_base.tiktoken
# o200k_base.tiktoken
# CompletedProcess(args=['ls', '/kaggle/tmp/setup/tiktoken_encodings'], returncode=0)

# %%
for k, v in [('TRANSFORMERS_NO_TF', '1'), ('TRANSFORMERS_NO_FLAX', '1'), ('CUDA_VISIBLE_DEVICES', '0'),
             ('TOKENIZERS_PARALLELISM', 'false'), ('TRITON_PTXAS_PATH', '/usr/local/cuda/bin/ptxas'),
             ('TIKTOKEN_ENCODINGS_BASE', '/kaggle/tmp/setup/tiktoken_encodings')]:
    os.environ[k] = v

# %%
from typing import Optional
from jupyter_client import KernelManager
from collections import Counter, defaultdict
from concurrent.futures import as_completed, ThreadPoolExecutor
import pandas as pd, polars as pl
from openai import OpenAI
from openai_harmony import (HarmonyEncodingName, load_harmony_encoding, SystemContent, ReasoningEffort, 
                             ToolNamespaceConfig, Author, Message, Role, TextContent, Conversation)
from transformers import set_seed
import kaggle_evaluation.aimo_3_inference_server

# %%
class CFG:
    system_prompt = ('You are a world-class International Mathematical Olympiad (IMO) competitor. '
                    'The final answer must be a non-negative integer between 0 and 99999. '
                    'You must place the final integer answer inside \\boxed{}.')
    tool_prompt = ('Use this tool to execute Python code. The environment is a stateful Jupyter notebook. '
                  'You must use print() to output results.')
    preference_prompt = 'You have access to `math`, `numpy` and `sympy` to solve the problem.'
    served_model_name, model_path = 'gpt-oss', '/kaggle/input/gpt-oss-120b/transformers/default/1'
    kv_cache_dtype, dtype = 'fp8_e4m3', 'auto'
    high_problem_timeout, base_problem_timeout = 900, 270
    notebook_limit, server_timeout = 17400, 180
    session_timeout, jupyter_timeout, sandbox_timeout = 960, 6, 3
    stream_interval, context_tokens, buffer_tokens, search_tokens = 200, 65536, 512, 32
    top_logprobs, batch_size, early_stop, attempts, workers, turns = 5, 256, 4, 8, 16, 128
    gpu_memory_utilization, temperature, min_p, seed = 0.96, 1.0, 0.02, 42
    debug_trace = True

# %%
set_seed(CFG.seed)

# %%
class AIMO3Template:
    def get_system_content(self, prompt, tool_cfg):
        return SystemContent.new().with_model_identity(prompt).with_reasoning_effort(
            reasoning_effort=ReasoningEffort.HIGH).with_tools(tool_cfg)
    
    def apply_chat_template(self, sys_prompt, usr_prompt, tool_cfg):
        return [Message.from_role_and_content(Role.SYSTEM, self.get_system_content(sys_prompt, tool_cfg)),
                Message.from_role_and_content(Role.USER, usr_prompt)]

# %%
class AIMO3Sandbox:
    _port_lock, _next_port = threading.Lock(), 50000
    
    @classmethod
    def _get_next_ports(cls, count=5):
        with cls._port_lock:
            ports = list(range(cls._next_port, cls._next_port + count))
            cls._next_port += count
            return ports
    
    def __init__(self, timeout):
        self._default_timeout, self._owns_kernel, self._client, self._km = timeout, False, None, None
        ports = self._get_next_ports(5)
        env = os.environ.copy()
        env.update({'PYDEVD_DISABLE_FILE_VALIDATION': '1', 'PYDEVD_WARN_EVALUATION_TIMEOUT': '0',
                   'JUPYTER_PLATFORM_DIRS': '1', 'PYTHONWARNINGS': 'ignore', 'MPLBACKEND': 'Agg'})
        self._km = KernelManager()
        self._km.shell_port, self._km.iopub_port, self._km.stdin_port, self._km.hb_port, self._km.control_port = ports
        self._km.start_kernel(env=env, extra_arguments=['--Application.log_level=CRITICAL'])
        self._client = self._km.blocking_client()
        self._client.start_channels()
        self._client.wait_for_ready(timeout=self._default_timeout)
        self._owns_kernel = True
        self.execute('import math, numpy, sympy, mpmath, itertools, collections\nmpmath.mp.dps = 64\n')
    
    def _format_error(self, tb):
        return ''.join(re.sub(r'\x1b\[[0-9;]*m', '', f) for f in tb 
                      if 'File "' not in f or 'ipython-input' in f)
    
    def execute(self, code, timeout=None):
        effective_timeout = timeout or self._default_timeout
        msg_id = self._client.execute(code, store_history=True, allow_stdin=False, stop_on_error=False)
        stdout, stderr, start = [], [], time.time()
        while True:
            if time.time() - start > effective_timeout:
                self._km.interrupt_kernel()
                return f'[ERROR] Execution timed out after {effective_timeout} seconds'
            try:
                msg = self._client.get_iopub_msg(timeout=1.0)
            except queue.Empty:
                continue
            if msg.get('parent_header', {}).get('msg_id') != msg_id: continue
            mt, c = msg.get('msg_type'), msg.get('content', {})
            if mt == 'stream':
                (stdout if c.get('name') == 'stdout' else stderr).append(c.get('text', ''))
            elif mt == 'error':
                stderr.append(self._format_error(c.get('traceback', [])))
            elif mt in {'execute_result', 'display_data'}:
                if txt := c.get('data', {}).get('text/plain'):
                    stdout.append(txt if txt.endswith('\n') else f'{txt}\n')
            elif mt == 'status' and c.get('execution_state') == 'idle':
                break
        out, err = ''.join(stdout), ''.join(stderr)
        return f'{out.rstrip()}\n{err}' if err and out else (err or out or '[WARN] No output. Use print() to see results.')
    
    def close(self):
        with contextlib.suppress(Exception):
            if self._client: self._client.stop_channels()
        if self._owns_kernel and self._km:
            with contextlib.suppress(Exception): self._km.shutdown_kernel(now=True)
            with contextlib.suppress(Exception): self._km.cleanup_resources()
    
    def reset(self):
        self.execute('%reset -f\nimport math, numpy, sympy, mpmath, itertools, collections\nmpmath.mp.dps = 64\n')
    
    def __del__(self):
        self.close()

# %%
class AIMO3Tool:
    def __init__(self, timeout, prompt, sandbox=None):
        self._local_jupyter_timeout, self._tool_prompt, self._jupyter_session = timeout, prompt, sandbox
        self._owns_session, self._execution_lock, self._init_lock = sandbox is None, threading.Lock(), threading.Lock()
    
    def _ensure_session(self):
        if self._jupyter_session is None:
            with self._init_lock:
                if self._jupyter_session is None:
                    self._jupyter_session = AIMO3Sandbox(timeout=self._local_jupyter_timeout)
    
    def _ensure_last_print(self, code):
        lines = code.strip().split('\n')
        if not lines: return code
        last = lines[-1].strip()
        if any(x in last for x in ['print', 'import']) or not last or last.startswith('#'): return code
        lines[-1] = 'print(' + last + ')'
        return '\n'.join(lines)
    
    @property
    def instruction(self): return self._tool_prompt
    
    @property
    def tool_config(self): return ToolNamespaceConfig(name='python', description=self.instruction, tools=[])
    
    def _make_response(self, output, channel=None):
        msg = Message(author=Author(role=Role.TOOL, name='python'), 
                     content=[TextContent(text=output)]).with_recipient('assistant')
        return msg.with_channel(channel) if channel else msg
    
    def process_sync_plus(self, message):
        self._ensure_session()
        final_script = self._ensure_last_print(message.content[0].text)
        with self._execution_lock:
            try:
                output = self._jupyter_session.execute(final_script)
            except TimeoutError as exc:
                output = f'[ERROR] {exc}'
        return [self._make_response(output, channel=message.channel)]

# %%
class AIMO3Solver:
    def __init__(self, cfg, port=8000):
        self.cfg, self.port = cfg, port
        self.base_url, self.api_key = f'http://0.0.0.0:{port}/v1', 'sk-local'
        self.template, self.encoding = AIMO3Template(), load_harmony_encoding(HarmonyEncodingName.HARMONY_GPT_OSS)
        self.stop_token_ids = self.encoding.stop_tokens_for_assistant_actions()
        self._preload_model_weights()
        self.server_process = self._start_server()
        self.client = OpenAI(base_url=self.base_url, api_key=self.api_key, timeout=self.cfg.session_timeout)
        self._wait_for_server()
        self._initialize_kernels()
        self.notebook_start_time, self.problems_remaining = time.time(), 50
    
    def _preload_model_weights(self):
        print(f'Loading model weights from {self.cfg.model_path} into OS Page Cache...')
        start, files, total = time.time(), [], 0
        for root, _, fnames in os.walk(self.cfg.model_path):
            for fn in fnames:
                fp = os.path.join(root, fn)
                if os.path.isfile(fp):
                    files.append(fp)
                    total += os.path.getsize(fp)
        with ThreadPoolExecutor(max_workers=self.cfg.workers) as ex:
            list(ex.map(lambda p: open(p, 'rb').read(), files))
        print(f'Processed {len(files)} files ({total/1e9:.2f} GB) in {time.time()-start:.2f} seconds.\n')
    
    def _start_server(self):
        cmd = [sys.executable, '-m', 'vllm.entrypoints.openai.api_server', '--seed', str(self.cfg.seed),
               '--model', self.cfg.model_path, '--served-model-name', self.cfg.served_model_name,
               '--tensor-parallel-size', '1', '--max-num-seqs', str(self.cfg.batch_size),
               '--gpu-memory-utilization', str(self.cfg.gpu_memory_utilization), '--host', '0.0.0.0',
               '--port', str(self.port), '--dtype', self.cfg.dtype, '--kv-cache-dtype', self.cfg.kv_cache_dtype,
               '--max-model-len', str(self.cfg.context_tokens), '--stream-interval', str(self.cfg.stream_interval),
               '--async-scheduling', '--disable-log-stats', '--enable-prefix-caching']
        self.log_file = open('vllm_server.log', 'w')
        return subprocess.Popen(cmd, stdout=self.log_file, stderr=subprocess.STDOUT, start_new_session=True)
    
    def _wait_for_server(self):
        print('Waiting for vLLM server...')
        start = time.time()
        for _ in range(self.cfg.server_timeout):
            if (rc := self.server_process.poll()) is not None:
                self.log_file.flush()
                raise RuntimeError(f'Server died with code {rc}. Full logs:\n{open("vllm_server.log").read()}\n')
            try:
                self.client.models.list()
                print(f'Server is ready (took {time.time()-start:.2f} seconds).\n')
                return
            except Exception:
                time.sleep(1)
        raise RuntimeError('Server failed to start (timeout).\n')
    
    def _initialize_kernels(self):
        print(f'Initializing {self.cfg.workers} persistent Jupyter kernels...')
        start = time.time()
        self.sandbox_pool = queue.Queue()
        with ThreadPoolExecutor(max_workers=self.cfg.workers) as ex:
            for future in as_completed([ex.submit(lambda: AIMO3Sandbox(timeout=self.cfg.jupyter_timeout)) 
                                       for _ in range(self.cfg.workers)]):
                self.sandbox_pool.put(future.result())
        print(f'Kernels initialized in {time.time()-start:.2f} seconds.\n')
    
    def _scan_for_answer(self, text):
        for pattern in [r'\\boxed\s*\{\s*([0-9,]+)\s*\}', r'final\s+answer\s+is\s*([0-9,]+)']:
            if matches := re.findall(pattern, text, re.IGNORECASE):
                try:
                    val = int(matches[-1].replace(',', ''))
                    if 0 <= val <= 99999: return val
                except ValueError: pass
        return None
    
    def _compute_mean_entropy(self, logprobs):
        if not logprobs: return float('inf')
        total, count = 0.0, 0
        for top_lp in logprobs:
            if isinstance(top_lp, dict) and top_lp:
                ent = sum(-math.exp(lp)*math.log2(math.exp(lp)) for lp in top_lp.values() if math.exp(lp) > 0)
                total += ent
                count += 1
        return total/count if count else float('inf')
    
    def _process_attempt(self, problem, sys_prompt, idx, stop_evt, deadline):
        if stop_evt.is_set() or time.time() > deadline:
            return {'Attempt': idx+1, 'Answer': None, 'Python Calls': 0, 'Python Errors': 0, 
                   'Response Length': 0, 'Entropy': float('inf')}
        local_tool, sandbox, py_calls, py_errs, total_toks, ans, logprobs = None, None, 0, 0, 0, None, []
        full_text = ""          # LLM entire output
        python_trace = []       # Python call history
        seed = int(math.pow(self.cfg.seed + idx, 2))
        try:
            sandbox = self.sandbox_pool.get(timeout=self.cfg.sandbox_timeout)
            local_tool = AIMO3Tool(self.cfg.jupyter_timeout, self.cfg.tool_prompt, sandbox)
            conv = Conversation.from_messages(self.template.apply_chat_template(
                sys_prompt, problem, local_tool.tool_config))
            for _ in range(self.cfg.turns):
                if stop_evt.is_set() or time.time() > deadline: break
                prompt_ids = self.encoding.render_conversation_for_completion(conv, Role.ASSISTANT)
                if (max_toks := self.cfg.context_tokens - len(prompt_ids)) < self.cfg.buffer_tokens: break
                stream = self.client.completions.create(model=self.cfg.served_model_name, 
                    temperature=self.cfg.temperature, logprobs=self.cfg.top_logprobs, max_tokens=max_toks,
                    prompt=prompt_ids, seed=seed, stream=True, extra_body={
                        'min_p': self.cfg.min_p, 'stop_token_ids': self.stop_token_ids, 'return_token_ids': True})
                try:
                    tok_buf, txt_chunks = [], []
                    for chunk in stream:
                        if stop_evt.is_set() or time.time() > deadline: break
                        if new_toks := chunk.choices[0].token_ids:
                            tok_buf.extend(new_toks)
                            total_toks += len(new_toks)
                            txt_chunks.append(chunk.choices[0].text)
                            full_text += chunk.choices[0].text
                            
                            if (clp := chunk.choices[0].logprobs) and clp.top_logprobs:
                                logprobs.extend(clp.top_logprobs)
                        if '}' in chunk.choices[0].text and (ans := self._scan_for_answer(
                            ''.join(txt_chunks[-self.cfg.search_tokens:]))):
                            break
                finally:
                    stream.close()
                if ans or not tok_buf: break
                new_msgs = self.encoding.parse_messages_from_completion_tokens(tok_buf, Role.ASSISTANT)
                conv.messages.extend(new_msgs)
                last = new_msgs[-1]
                if last.channel == 'final':
                    ans = self._scan_for_answer(last.content[0].text)
                    break
                if last.recipient == 'python':
                    py_calls += 1
                    py_code = last.content[0].text
                    resp = local_tool.process_sync_plus(last)
                    py_out = resp[0].content[0].text

                    python_trace.append({
                        "code": py_code,
                        "output": py_out,
                        "channel": last.channel,
                    })
                    
                    if any(x in (txt := resp[0].content[0].text) for x in ['[ERROR]', 'Traceback', 'Error:']):
                        py_errs += 1
                    conv.messages.extend(resp)
        except Exception: py_errs += 1
        finally:
            if sandbox:
                sandbox.reset()
                self.sandbox_pool.put(sandbox)
        return {'Attempt': idx+1,
                'Response Length': total_toks,
                'Python Calls': py_calls,
                'Python Errors': py_errs,
                'Entropy': self._compute_mean_entropy(logprobs),
                'Answer': ans,
                'Full Text': full_text,
                'Python Trace': python_trace,
               }
    
    def _select_answer(self, results):
        ans_weights, ans_votes = defaultdict(float), defaultdict(int)
        for r in results:
            if (a := r['Answer']) is not None:
                ans_weights[a] += 1.0/max(r['Entropy'], 1e-9)
                ans_votes[a] += 1
        scored = sorted([{'answer': a, 'votes': ans_votes[a], 'score': w} 
                        for a, w in ans_weights.items()], key=lambda x: x['score'], reverse=True)
        display(pd.DataFrame([(s['answer'], s['votes'], s['score']) for s in scored], 
                            columns=['Answer', 'Votes', 'Score']).round({'Score': 3}))
        final = scored[0]['answer'] if scored else 0

        # Among attempts: Final answer and Minimum entropy
        chosen = None
        cand = [r for r in results if r.get('Answer') == final]    # For test, GT instead of final
        if cand:
            chosen = min(cand, key=lambda r: r.get('Entropy', float('inf')))

        # Parsing for readability
        llm_full_output = chosen.get('Full Text', '')
        llm_full_output = llm_full_output.replace(
            "assistantanalysis to=python code",
            "\n\n[assistantanalysis to=python code]\n"
        )
        llm_full_output = re.sub(r"analysis(?=\S)", "\n[analysis]\n", llm_full_output)

        # Print
        if getattr(self.cfg, "debug_trace", False) and chosen is not None:
            print("========== CHOSEN ATTEMPT TRACE ==========")
            print(f"Attempt: {chosen.get('Attempt')}, Answer: {chosen.get('Answer')}, Entropy: {chosen.get('Entropy')}")
            print("\n--- LLM FULL OUTPUT ---\n")
            print(llm_full_output)

            print("\n--- PYTHON CALLS ---\n")
            for j, t in enumerate(chosen.get('Python Trace', []), 1):
                print(f"[Python Call {j}]")
                print("CODE:")
                print(t.get("code", ""))
                print("\nOUTPUT:")
                print(t.get("output", ""))
                print("\n" + "-"*40 + "\n")
        
        print(f'\nFinal Answer: {final}\n')
        return final
    
    def solve_problem(self, problem):
        print(f'\nProblem: {problem}\n')      
        user_input = f'{problem} {self.cfg.preference_prompt}'
        time_left = self.cfg.notebook_limit - (time.time() - self.notebook_start_time)
        budget = max(self.cfg.base_problem_timeout, 
                    min(time_left - max(0, self.problems_remaining-1)*self.cfg.base_problem_timeout, 
                        self.cfg.high_problem_timeout))
        deadline = time.time() + budget
        print(f'Budget: {budget:.2f} seconds | Deadline: {deadline:.2f}\n')
        results, valid, stop_evt = [], [], threading.Event()
        with ThreadPoolExecutor(max_workers=self.cfg.workers) as ex:
            futures = [ex.submit(self._process_attempt, user_input, self.cfg.system_prompt, i, stop_evt, deadline)
                      for i in range(self.cfg.attempts)]
            for future in as_completed(futures):
                try:
                    if (r := future.result())['Answer'] is not None:
                        valid.append(r['Answer'])
                    results.append(r)
                    if (cnts := Counter(valid).most_common(1)) and cnts[0][1] >= self.cfg.early_stop:
                        stop_evt.set()
                        for f in futures: f.cancel()
                        break
                except Exception as exc:
                    print(f'Future failed: {exc}')
        self.problems_remaining = max(0, self.problems_remaining - 1)
        if results:
            df = pd.DataFrame(results)
            df['Entropy'] = df['Entropy'].round(3)
            df['Answer'] = df['Answer'].astype('Int64')
            display(df)
        return self._select_answer(results) if valid else 0
    
    def __del__(self):
        if hasattr(self, 'server_process'):
            self.server_process.terminate()
            self.server_process.wait()
        if hasattr(self, 'log_file'): self.log_file.close()
        if hasattr(self, 'sandbox_pool'):
            while not self.sandbox_pool.empty():
                with contextlib.suppress(Exception): self.sandbox_pool.get_nowait().close()

# %%
solver = AIMO3Solver(CFG)
# Out:
# Loading model weights from /kaggle/input/gpt-oss-120b/transformers/default/1 into OS Page Cache...
# Processed 26 files (65.28 GB) in 68.08 seconds.
#
# Waiting for vLLM server...
# Server is ready (took 119.28 seconds).
#
# Initializing 16 persistent Jupyter kernels...
# Kernels initialized in 2.73 seconds.

# %%
def predict(id_: pl.DataFrame, question: pl.DataFrame, answer: Optional[pl.DataFrame] = None) -> pl.DataFrame:    
    gc.disable()
    final_answer = solver.solve_problem(question.item(0))
    gc.enable()
    gc.collect()
    return pl.DataFrame({'id': id_.item(0), 'answer': final_answer})

# %%
inference_server = kaggle_evaluation.aimo_3_inference_server.AIMO3InferenceServer(predict)
if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    # inference_server.run_local_gateway(('/kaggle/input/ai-mathematical-olympiad-progress-prize-3/test.csv',))
    inference_server.run_local_gateway(('/kaggle/input/datasets/lockway/aimo-aiku-test/difficult.csv',))
# Out:
# Problem: Let $n \geq 6$ be a positive integer. We call a positive integer $n$-Norwegian if it has three distinct positive divisors whose sum is equal to $n$. Let $f(n)$ denote the smallest $n$-Norwegian positive integer. Let $M=3^{2025!}$ and for a non-negative integer $c$ define
# \begin{equation*}
#     g(c)=\frac{1}{2025!}\left\lfloor \frac{2025! f(M+c)}{M}\right\rfloor.
# \end{equation*}
# We can write
# \begin{equation*}
#     g(0)+g(4M)+g(1848374)+g(10162574)+g(265710644)+g(44636594)=\frac{p}{q}
# \end{equation*}
# where $p$ and $q$ are coprime positive integers. What is the remainder when $p+q$ is divided by $99991$?
#
# Budget: 900.00 seconds | Deadline: 1771434452.45
#    Attempt  Response Length  Python Calls  Python Errors  Entropy  Answer  \
# 0        4            26464            76              2    0.714    8687
# 1        6            35231            36              3    0.729      14
# 2        2            40106            45              4    0.683   51379
# 3        7            44904            79              3    0.712   41754
# 4        3            46091            71              9    0.732   41754
# 5        1            53286            61             20    0.712      60
# 6        5            54956            40              6    0.668   41754
# 7        8            60432           113             11    0.666    <NA>
#
#                                            Full Text  \
# 0  analysisWe need to parse problem statement ful...
# 1  analysisWe need to parse the problem carefully...
# 2  analysisWe have a challenging combinatorial nu...
# 3  analysisWe need to compute for each c (non-neg...
# 4  analysisWe need to parse problem. We have n ≥ ...
# 5  analysisWe need to parse the problem and solve...
# 6  analysisWe need to parse problem:\n\nDefine "n...
# 7  analysisWe need to compute p+q mod 99991 for e...
#
#                                         Python Trace
# 0  [{'code': 'import math, itertools, sys, functo...
# 1  [{'code': 'def f_brutal(n, max_x=5000):
#     fo...
# 2  [{'code': 'def min_max_distinct_sum(n):
#     mi...
# 3  [{'code': 'import math
# from functools import l...
# 4  [{'code': 'def is_sum_two_distinct_powers_of_3...
# 5  [{'code': 'import sympy as sp
#
# def is_norwegia...
# 6  [{'code': 'import sympy as sp
#
# cs = [0, None, ...
# 7  [{'code': 'def f_brutal(n, limit=10000):
#     #...
#    Answer  Votes  Score
# 0   41754      3  4.267
# 1   51379      1  1.463
# 2      60      1  1.405
# 3    8687      1  1.401
# 4      14      1  1.372
# ========== CHOSEN ATTEMPT TRACE ==========
# Attempt: 4, Answer: 8687, Entropy: 0.713724135183571
#
# --- LLM FULL OUTPUT ---
#
#
# [analysis]
# We need to parse problem statement fully.
#
# We have $n \ge 6$ be positive integer. We call a positive integer $k$ "n-Norwegian" if it has three distinct positive divisors whose sum equals $n$.
#
# Thus for each $n$, we define $f(n)$ = the smallest positive integer that is n-Norwegian.
#
# Then we define $M = 3^{2025!}$.
#
# Define for non-negative integer $c$:
# $$
# g(c) = \frac{1}{2025!}\left\lfloor \frac{2025! f(M+c)}{M} \right\rfloor.
# $$
#
# We consider sum $S = g(0)+g(4M)+g(1848374)+g(10162574)+g(265710644)+g(44636594)$.
#
# We can write $S = p/q$ reduced fraction; find $(p+q) \mod 99991$.
#
# We need to compute the sum rationally. Might involve large numbers but we can derive pattern.
#
# First we must understand f(n). For each n≥6, we need smallest integer that has three distinct divisors whose sum = n.
#
# Divisors distinct: positive divisors a,b,c distinct. Could be any three divisors of integer x (including 1 and x). Sum of those three divisors equal n.
#
# Thus we must find for each n minimal integer k such that there exist three distinct divisors of k summing to n.
#
# We can think of small numbers.
#
# But we have n = M + c for many large numbers, where M is huge 3^{2025!}. So f(M+c) might be small relative? Actually M is huge; maybe f(M+c) is something like (M + c) - something? Wait maybe f(n) is something like n-? Not exactly.
#
# Observation: For any integer n≥6, we can consider integer k = n - 1? Not necessarily has three divisors.
#
# But we need minimal k such that there exist three distinct divisors a,b,c of k with sum n. Equivalent to find minimal integer having a+b+c = n, where a,b,c are divisors of that integer and distinct.
#
# One naive construction: Choose k = n. Then divisors 1, something? But n is divisor of itself, but need three distinct. Usually we can pick 1, n, and another divisor d (distinct from 1 and n). Sum = 1 + n + d = n => 1 + d = 0 impossible. So k = n won't work.
#
# Maybe we can pick integer k = n - 2? Divisors maybe 1,2,k? Let's try: if we pick k such that 1,2,k are divisors (k must be at least 2 and divisible by 2). Sum = 1+2+k = n => k = n-3. So we need integer k that is even (divisible by 2) and equals n-3. So condition: n-3 is even => n odd. And also k (n-3) must be divisible by 2 (true if n odd). So for odd n≥7 (since n-3≥4), we can take k = n-3 (even). It will have divisors 1,2,k (since k is even). Are they distinct? Yes as long as k>2. So for odd n≥7, we have that k works, i.e., f(n) ≤ n-3. Is it minimal? Could be smaller.
#
# Also for even n, maybe we can use divisors 1,3,k? Sum = 1+3+k = n => k = n-4. Need k divisible by 3. So condition: n-4 ≡0 (mod 3) i.e., n ≡1 (mod 3). And need k distinct from 1,3 (i.e., k>3). So for n ≡ 1 mod 3, n≥... we have candidate k = n-4 (multiple of 3). Also need k positive integer. That gives f(n) ≤ n-4.
#
# We must find the minimal possible k (i.e., small integer) for given n.
#
# Observation: Because we can choose arbitrary three divisors that sum to n, we may try to make k as small as possible by using large divisor values? Wait the sum is fixed n, but the integer k is the product? Actually we only need divisors of k, not necessarily product; the divisor values are a,b,c and must divide k, i.e., k is a multiple of each of them. Therefore k must be a common multiple of a,b,c: i.e., divisible by lcm(a,b,c). The smallest integer having these divisors is lcm(a,b,c) perhaps? Actually if a,b,c are divisors of k, then k is a multiple of each. The smallest positive integer that has these as divisors is L = lcm(a,b,c). L has all these as divisors; indeed they divide L. Also they are distinct. So for given a,b,c with sum=n, the minimal possible integer that is n-Norwegian is at least L = lcm(a,b,c). And f(n) = min over distinct a,b,c positive integers with sum=n of lcm(a,b,c). So we need to compute minimal lcm given sum.
#
# Thus the problem reduces to: For given n, find min lcm of three distinct positive integers a,b,c sum to n.
#
# Now for huge n like M+c, we need minimal lcm, which may be relatively small.
#
# Because we can pick small numbers that sum to large n? Wait sum must be n, so if we pick small a,b and large c to meet sum, lcm will be large due to large c maybe. However we can arrange to have a,b,c large but maybe lcm can be kept moderate if they share factors.
#
# But the sum is huge (on the order of 3^{2025!}), which is astronomically large. To get minimal lcm, we might use a,b,c that are approximately n/3 each, but then lcm huge. However we could consider using numbers that are divisors of a large common multiple that's not too large? Actually we can pick a,b,c that are divisors of some relatively small integer L, while still sum to huge n. But can three divisors of a small integer L sum to a huge n? Since the maximum divisor of L is L itself, the sum of three distinct divisors is at most L + (L/2) + (L/3) maybe. Actually maximum sum would involve the three largest distinct divisors, which are L (the integer itself), then maybe the second largest divisor is at most L/2, third largest at most L/3 (if L is composite). So sum ≤ L + L/2 + L/3 = (1 + 1/2 + 1/3)L = (11/6)L ≈ 1.833L. So for given sum n, we need L at least about 0.547 n (since L >= n*6/11). So L must be at least about 0.55 n. Thus minimal lcm cannot be small relative to n, it's at least linear in n.
#
# But maybe there are special cases: If L is a prime, its only divisors are 1 and itself. Can't have three distinct divisors. So need L composite, at least with 3 divisors.
#
# Thus f(n) will be around n/?, maybe close to n/2? Let's examine.
#
# Observation: For odd n, we constructed candidate k = n-3 with divisors 1,2,k, lcm = LCM(1,2,k) = LCM(2,k) = if k even, lcm = k (since k is multiple of 2). So L = n-3. So f(n) ≤ n-3. That's linear, with coefficient 1.
#
# But can we get smaller than n-3? We can try to find a,b,c distinct positive integers with sum n and lcm less than n-3.
#
# But LCM cannot be less than max among them (since max divides LCM). If we let c be the largest of the three numbers, then L ≥ c. And sum = a+b+c = n, with a,b positive distinct and less than c. So c > n/3 (since others at least 1 each). Minimal possible L is at least ceil(n/3). So f(n) ≥ ceil(n/3). That's a trivial lower bound. So f(n) might be around n/2.
#
# Our candidate L = n-3 is much larger than n/3; perhaps we can get much smaller L if we choose numbers that are not as large as n-3 but still sum to n.
#
# For example, suppose we choose a,b,c all about n/3. Then the LCM may be about that size as well, maybe slightly larger due to not sharing factors.
#
# Goal is to minimize the LCM given sum n. Since we want L small relative to n, we need to have c not too large; i.e., we want all three numbers comparable.
#
# Thus maybe the minimal LCM for large n is about n/2? Let's test with small n via brute force to see pattern.
#
# Compute f(n) for n up to maybe 100, by brute force enumerating triples a<b<c distinct, a+b+c=n, compute L=lcm(a,b,c), take min. Let's code in Python.
#
#
#
# [assistantanalysis to=python code]
# import math, itertools, sys, functools, collections, math, itertools, random, sys, sympy as sp, numpy as np, math, itertools, random
# [analysis]
# Let's compute f(n) for n up to maybe 200 and see pattern.
#
# [assistantanalysis to=python code]
# def f_brutal(n):
#     min_l = None
#     best = None
#     # distinct positive integers a<b<c such that sum=n
#     for a in range(1, n):
#         for b in range(a+1, n):
#             c = n - a - b
#             if c <= b:  # need c>b
#                 continue
#             # now distinct a<b<c
#             # compute lcm
#             l = math.lcm(a,b,c)
#             if min_l is None or l < min_l:
#                 min_l = l
#                 best = (a,b,c)
#     return min_l, best
#
# values = [f_brutal(n)[0] for n in range(6,101)]
# values[:20]
#
# [analysis]
# Wait for n=6, min lcm=6 (triple 1,2,3? sum 6; lcm=6). n=7 => min lcm=4 (triple? Let's check).
#
# [assistantanalysis to=python code]
# f_brutal(7)
#
# [analysis]
# Indeed a,b,c=1,2,4 sum=7, lcm=4. That's less than n-3=4; matches.
#
# n=8 => min lcm=6 (1,2,5?) Wait compute.
#
# [assistantanalysis to=python code]
# f_brutal(8)
#
# [analysis]
# Actually earlier list gave value 6 for n=8? Let's compute again. My earlier list for n=8 (n index starting at 6) gave 6 but maybe mis-calc. Let's compute again properly.
#
#
#
# [assistantanalysis to=python code]
# def f_brutal(n):
#     min_l = float('inf')
#     best=None
#     for a in range(1, n):
#         for b in range(a+1, n):
#             c = n-a-b
#             if c<=b: continue
#             l = math.lcm(a,b,c)
#             if l<min_l:
#                 min_l = l
#                 best=(a,b,c)
#     return min_l,best
#
# for n in range(6,21):
#     print(n, f_brutal(n))
#
# [analysis]
# Interesting: For n=8 min lcm=10 > n. For n=9 min lcm=6 (smaller). So f(n) is not monotonic.
#
# We need pattern for large n perhaps using simple construction.
#
# The problem is likely designed such that f(M+c) for those given c values are simple to compute, maybe all same values or small set.
#
# Given M is a huge power of 3, maybe we need to consider divisibility properties mod something.
#
# Note that f(n) depends only on n modulo something? Possibly modulo 3? Let's compute f for many n to see pattern periodic.
#
#
#
# [assistantanalysis to=python code]
# def f_brutal_limit(N):
#     res={}
#     for n in range(6,N+1):
#         l,_=f_brutal(n)
#         res[n]=l
#     return res
#
# # compute up to maybe 200
# vals=f_brutal_limit(200)
# # show pattern of differences maybe.
# list_vals=[vals[n] for n in range(6,51)]
# list_vals
#
# [analysis]
# Let's compute up to 300 maybe.
#
#
#
# [assistantanalysis to=python code]
# vals = f_brutal_limit(300)
# # Show for n from 6 to 100
# for n in range(6,101):
#     print(n, vals[n])
#
# [analysis]
# This looks messy but maybe for large n, f(n) is close to some multiple of 6? Let's analyze pattern: many values are multiples of 2, 4, 6, etc. Maybe minimal lcm tends to be the smallest even multiple that can be achieved.
#
# Let's try to guess that f(n) is the smallest even integer L such that there exist three distinct divisors of L summing to n. Since we can choose 1, 2, L (if L even). Sum = L+3? Wait 1+2+L = L+3 = n => L = n-3. So if n is odd, we can take L = n-3 even. So for odd n, f(n) <= n-3. But could there be smaller L? The smallest L would be at least maybe n/3. For odd n, n-3 is large, not minimal. Perhaps there exists some smaller L that works by choosing divisors other than 1,2,L.
#
# But from our data up to 100, for odd n, e.g., n=9, f(9)=6 (less than 9-3=6 equal). For n=11, f=6 (less). For n=13, f=8 (less than 10). For n=15, f=12 (less than 12). So f is less than n-3 often.
#
# Thus minimal L may be independent of n in many cases; for odd n small, we get values 6,8, etc.
#
# Perhaps general formula: for any n≥6, f(n) is the smallest number L such that there exist three distinct divisors a,b,c of L adding to n. Since we can choose divisors that are not necessarily 1 and 2.
#
# Observation: If L is even, we have divisors 1,2, and any other divisor d (distinct). The sum can be 1+2+d = n => d = n-3. For L even, we also need d dividing L. So requirement: there exists even L such that L is multiple of (n-3). Since we also have L itself as a divisor: Actually d must be divisor of L; not necessary that L equals d. L can be larger than d, but need 1 and 2 to also divide L (true for any even L). So we can choose L = multiple of (n-3), at least (n-3) itself; but also must be even. If (n-3) is even (n odd), then choose L = n-3 works (since even). If (n-3) odd (n even), then cannot use 1,2,d with d = n-3 because L must be even and multiple of (n-3) which is odd, but then L must be even multiple of odd number, smallest such is 2*(n-3). So for even n, we could possibly use L = 2*(n-3) if (n-3) odd. Then 1,2,d dividing L? d = n-3 divides L (since L = 2*(n-3)). Since L even, 1 and 2 are divisors. Then triple 1,2,d sum to n? Yes, 1+2+(n-3)=n. So for even n where n-3 odd, L=2(n-3) works. Let's test: n=8 even, n-3=5 odd => L = 10 (2*5). f(8)=10 indeed matches. n=10 even, n-3=7 odd => L=14? Wait f(10)=6 per table, not 14. So our candidate not minimal.
#
# So for n=10, we get a smaller L=6: with divisors maybe 2,3,? sum to 10: 2+3+5? but 5 not divisor of 6. Actually triple (1,3,6) sum=10, L=6 works: divisors 1,3,6 (all divide 6). So indeed we can do better.
#
# Thus we need to analyze generally minimal L.
#
# Observation: For any L, its divisors include 1 and L. Using 1 and L as two of the three divisors, the third divisor must be n-1-L. But must be positive and divide L, distinct from 1 and L.
#
# Thus we can try to find L such that there exists divisor d of L (distinct from 1 and L) with d = n-1-L. But note that n-1-L may be negative if L > n-1; we require positive, so L <= n-2. So minimal L less than n. So we are trying to find minimal L <= n-2 such that there exists a divisor d of L (different from 1 and L) with d = n-1-L. Or we could use 1 and 2 as small divisors.
#
# General problem: We have three distinct positive divisors a<b<c dividing L with a+b+c=n. Since we can reorder, we can think of picking a and b small, and c maybe large. For minimal L, we want c not too large, but L must be at least c.
#
# Idea: Since we can always use 1 and some other divisor d, maybe we can get small L by picking a divisor pair (a,b) that sum to small numbers, leaving large remainder as c. But c must also be a divisor. So we can think of L being any number that has two divisors a and b (distinct, maybe small), with remainder n - (a+b) = c also dividing L. So for a given L, we need two proper divisors a,b of L (possibly including 1) such that the third divisor c = n - a - b is also a divisor (distinct). So we can look for smallest L with such property.
#
# Thus the problem reduces to solving for each n: find minimal L such that there exist distinct divisors a,b,c of L adding to n. This can be approached algorithmically.
#
# But here n huge: M + c. However perhaps the minimal L is independent of the huge additive part c when M is a large power of 3. Because we may have many divisors due to powers of 3, maybe the minimal L is just some small power of 3 (like M itself)?? But note L must be at least as large as largest divisor among three, which cannot exceed L. So the minimal L might be small relative to n, but maybe depends on n modulo something (like modulo 3). Since M is power of 3, we have many divisors that are powers of 3.
#
# Potentially we may be able to construct three divisors of the form 3^a, 3^b, 3^c (distinct) that sum to n = M + c, because M is huge power of 3, maybe close to M itself. Let's examine.
#
# Let M = 3^T with T = 2025!. Then M is enormous but also a power of 3, so its divisors are exactly all powers 3^i for i=0..T. Distinct positive divisors are these powers. So the sum of three distinct powers of 3 could be made to equal n? Possibly by choosing 3^T = M and other small powers.
#
# Consider we pick a = M (3^T), b = 3^k, c = 3^\ell where k<ℓ<T. Sum = M + 3^k + 3^\ell = M + something small relative to M because M huge. The 'something' is at most 3^{T-1} + 3^{T-2} etc, which is still huge but smaller than M.
#
# But n = M + c0, with c0 up to maybe 10^9? Actually c values: 0, 4M, etc? Wait c are given: 0, 4M, 1848374, 10162574, 265710644, 44636594. Some c values are huge multiples of M? Actually 4M is 4 times M (which is huge). However note the definition: g(c) = floor(2025! * f(M + c) / M) / 2025!. So we need f(M + c). So for c like 4M, it's M + 4M = 5M (i.e., 5*3^T). That's also a multiple of M.
#
# But c's like 1848374 are small relative to M (since M is astronomically huge). So essentially n = M + small constant.
#
# Thus for n around M, we can try to find minimal L that yields sum to n. Since M is power of 3, we may get minimal L = M? Let's test small analog: Let's take a smaller exponent: Suppose M = 3^4=81. Compute f(M + c) for small c? Let's brute force for moderate M to see pattern. Use T small (like 5). Compute f(3^T + c) for small c for T maybe 6? Let's try.
#
#
#
# [assistantanalysis to=python code]
# def f_brutal_limit_fast(n):
#     # Use brute for moderate n maybe up to 5000
#     return f_brutal(n)[0]
#
# def compute_f_for_M_T(T, cs):
#     M = 3**T
#     results={}
#     for c in cs:
#         n = M + c
#         if n > 5000:
#             print("n too large for brute", n)
#             continue
#         results[c]=f_brutal_limit_fast(n)
#     return results
#
# # Example T=5 (M=243)
# cs = [0, 4*3**5, 1848, 10162, 265710, 44636]  # scaled small values? Not realistic but for test.
# print(compute_f_for_M_T(5, [0, 1, 10, 20, 100]))
#
# [analysis]
# This seems messy; maybe not correct.
#
# But we cannot brute for huge M. Instead we need to find formula for f(n). Let's try to find general solution.
#
# Given sum n, we want minimal L (i.e., f(n)). Since L is at least max divisor c = n - a - b. To minimize L, we can try to make a and b as large as possible (subject to being divisors of L and distinct from c). However a and b also must be divisors of L, and they must be ≤ L. To have small L relative to n, we need c close to L, but also a,b also near L perhaps; but if a and b are large, they may be close to L, but then sum a+b+c will exceed n unless n large. Not helpful.
#
# Instead, perhaps we can use divisors that are multiples of each other, because L must be multiple of each. The LCM of a,b,c is at most product of maximal exponents.
#
# Observation: If we set a = d, b = 2d, c = 3d (distinct) then their sum = 6d. LCM = lcm(d,2d,3d) = 6d. So L = 6d, sum = 6d, thus n = 6d leads to f(n) <= 6d = n. But we need n maybe not multiple of 6.
#
# We can adjust scaling.
#
# In general, if we have numbers x*d, y*d, z*d where x,y,z are distinct positive integers with gcd(x,y,z)=1, then LCM = lcm(x,y,z)*d. For sum = (x+y+z)*d = n. So L = lcm(x,y,z)* (n / (x+y+z)). To minimize L for given n, we want to choose small x,y,z with small lcm/(sum). Because d = n/(x+y+z) must be integer (so (x+y+z) must divide n). So minimal L can be achieved by picking triple (x,y,z) such that (x+y+z) divides n and lcm(x,y,z) is small relative to (x+y+z).
#
# Hence f(n) = min_{triples (x,y,z) distinct positive ints, x<y<z, (x+y+z) | n} (lcm(x,y,z) * (n/(x+y+z))). This seems plausible because we can set d = n/(x+y+z) (must be integer). Then choose a = x*d, b = y*d, c = z*d. Since d times each, LCM = d * lcm(x,y,z). Indeed those a,b,c are divisors of L = d * lcm(x,y,z). Actually L = lcm(a,b,c) = d * lcm(x,y,z). That L yields triple sum = n.
#
# Thus minimal L is indeed achieved by scaling a base triple (x,y,z) (primitive pattern) by factor d (positive integer). So f(n) = n * min_{primitive triple (x,y,z)} (lcm(x,y,z)/(x+y+z)), where the min is over triples such that (x+y+z) divides n? Wait the factor d must be integer; given n, we need (x+y+z) | n to have integer scaling factor d.
#
# Thus for each divisor s of n (where s = x+y+z), we can get L = (n/s) * lcm(x,y,z). So f(n) = min_{triples (x,y,z) distinct, s=x+y+z dividing n} (n * lcm(x,y,z)/s). The factor n can be pulled out: f(n) = n * min_{triples with s|n} (lcm(x,y,z)/s). So f(n) is n times a factor that depends only on n via allowed s.
#
# Thus f(n)/n = min_{(x,y,z) distinct, s=x+y+z | n} (lcm(x,y,z)/s). Let's denote r(s) = min_{triple with sum s} (lcm(x,y,z)/s). Then f(n) = n * min_{s|n, s>=6} r(s). Because s must be at least 1+2+3=6 minimal sum for distinct positive integers.
#
# Thus f(n)/n = min_{s|n} r(s). Since r(s) depends only on s, not on n (except which s divisors are available). So f(n) = n * m where m = min_{s|n} r(s). This yields a multiplicative property.
#
# Thus to compute f for huge n, we need to examine divisors s of n. n is M+c, where M huge; divisors maybe limited. But perhaps the minimal r(s) is achieved by s=6 (the smallest possible sum) because r(6) is maybe something like lcm(1,2,3)/6 = 6/6 = 1. Indeed triple (1,2,3) sum 6, lcm=6, ratio=1. So r(6)=1.
#
# Thus if n is divisible by 6, we have f(n) ≤ n * 1 = n. Actually we can get L = n * (6/6) = n. Wait scaling: d = n/6, then a=1*d=n/6, b=2*d=n/3, c=3*d=n/2. LCM = d*6 = n. Indeed n itself works with divisors n/6, n/3, n/2, which sum to n (since (n/6)+(n/3)+(n/2) = n*(1/6+1/3+1/2)=n). Are those integers? Need n divisible by 6 to make these integers distinct. So if n divisible by 6, we have f(n) ≤ n. But could be smaller than n? Let's see ratio r(6)=1 gives f(n)=n. Could we do better ratio < 1? Possibly r(s)<1 for some s? Since lcm(x,y,z) is at least max(x,y,z) which is at least s/3, ratio ≥ (s/3)/s = 1/3. So minimal possible ratio is at least 1/3. Let's search for s values giving ratio <1.
#
# Compute r(s) for s up to maybe 30.
#
#
#
# [assistantanalysis to=python code]
# def compute_r(limit):
#     r={}
#     for s in range(6,limit+1):
#         best=math.inf
#         for a in range(1,s):
#             for b in range(a+1,s):
#                 c=s-a-b
#                 if c<=b:
#                     continue
#                 # distinct automatically
#                 l=math.lcm(a,b,c)
#                 ratio=l/s
#                 if ratio<best:
#                     best=ratio
#         if best<math.inf:
#             r[s]=best
#     return r
#
# r_vals=compute_r(30)
# r_vals
#
# [analysis]
# Interesting: For s=7, ratio=4/7 ≈0.5714 (since best triple is (1,2,4) LCM 4 sum7). Indeed r(7) = 4/7.
#
# Thus the minimal ratio r(s) can be less than 1, as low as 4/7 approx .5714 for s=7, 0.54545 for s=11 (maybe triple 2,3,6? Actually 2+3+6=11, lcm 6 ratio 6/11≈0.5454). Similarly for s=13 ratio ~0.615.
#
# So minimal ratio may be as low as maybe 1/2? Let's search for larger s.
#
#
#
# [assistantanalysis to=python code]
# def best_triple_for_s(s):
#     best_ratio=math.inf
#     best_trip=None
#     for a in range(1,s):
#         for b in range(a+1,s):
#             c=s-a-b
#             if c<=b:
#                 continue
#             l=math.lcm(a,b,c)
#             ratio=l/s
#             if ratio<best_ratio:
#                 best_ratio=ratio
#                 best_trip=(a,b,c)
#     return best_ratio,best_trip
#
# for s in range(6,101):
#     r,b=best_triple_for_s(s)
#     if r<0.55:
#         print(s, r,b)
#
# [analysis]
# Interesting: s values multiples of 11? Actually s=11,22,... multiples of 11? Let's check pattern: s=11,22,33,... Indeed they are multiples of 11. The best triple is (2,3,6) scaled by factor s/11? Wait for s=11, triple (2,3,6). For s=22, triple (4,6,12) = 2*(2,3,6). For s=33, triple (6,9,18) = 3*(2,3,6). So pattern: base triple (2,3,6) sum 11, lcm 6, ratio 6/11 ≈0.5454. Scaling by factor k multiplies sum and lcm by k, ratio unchanged.
#
# Thus r(s) = 6/11 for any s that is multiple of 11? Not exactly; need s = k*11, triple scaled by k; lcm = 6k; ratio = 6k / 11k = 6/11. So indeed for any s divisible by 11, we can get ratio 6/11 using scaled (2,3,6). This is the minimal ratio found up to 100. Could there be a triple with lower ratio? Let's search up to maybe 300.
#
#
#
# [assistantanalysis to=python code]
# def compute_min_ratio(limit):
#     min_ratio = 1.0
#     min_s = None
#     best_trip=None
#     for s in range(6, limit+1):
#         ratio,trip=best_triple_for_s(s)
#         if ratio < min_ratio:
#             min_ratio=ratio
#             min_s=s
#             best_trip=trip
#     return min_ratio,min_s,best_trip
#
# compute_min_ratio(500)
#
# [analysis]
# So the minimal ratio up to 500 is indeed 6/11.
#
# Can we get lower ratio? Let's consider theoretical lower bound.
#
# We need distinct positive integers a,b,c with sum s, LCM L. Want L/s minimal.
#
# Take a,b,c as multiples of some d: a=x*d, b=y*d, c=z*d with gcd(x,y,z)=1 (otherwise we can factor). Then L = d * lcm(x,y,z). s = d * (x+y+z). Ratio = lcm(x,y,z)/(x+y+z). Since d cancels. So the minimal ratio across all triples equals minimal ratio of primitive triples (no common factor) of lcm/(sum). This ratio is independent of scaling. So we can find minimal ratio across all primitive triples. We found ratio 6/11 for (2,3,6) which is primitive because gcd(2,3,6)=1? gcd is 1? Actually gcd(2,3,6) = 1. Yes.
#
# Can we get ratio less than 6/11? Let's search systematically over primitive triples with limited sum.
#
# Search for small primitive triples up to say numbers <= 100 maybe.
#
#
#
# [assistantanalysis to=python code]
# def primitive_triples(limit):
#     mins = []
#     best_ratio=1
#     best_trip=None
#     for a in range(1,limit+1):
#         for b in range(a+1,limit+1):
#             for c in range(b+1,limit+1):
#                 if math.gcd(a, math.gcd(b,c)) != 1:
#                     continue
#                 # distinct positive integers, primitive
#                 s = a+b+c
#                 L = math.lcm(a,b,c)
#                 ratio=L/s
#                 if ratio < best_ratio:
#                     best_ratio=ratio
#                     best_trip=(a,b,c)
#     return best_ratio,best_trip
#
# primitive_triples(50)
#
# [analysis]
# Thus (2,3,6) appears to be minimal ratio among primitive triples with numbers up to 50. Could there be even lower ratio with larger numbers? Let's expand.
#
#
#
# [assistantanalysis to=python code]
# best_ratio,best_trip=primitive_triples(200)
# best_ratio,best_trip
#
# [analysis]
# Thus seems minimal ratio is 6/11 indeed.
#
# To be sure, maybe there is theoretical proof that ratio cannot be less than 6/11. Could be due to some inequality. Let's attempt to reason: For primitive triple (a,b,c) distinct, we need L = lcm(a,b,c) at least max(a,b,c). Let c be max. Since numbers distinct, we have a ≤ b < c.
#
# Given lcm = multiple of each, and at least c. Also a+b+c = s. We want minimize L/s.
#
# If c is large relative to sum, ratio may be high; we want L small relative to sum, so we need L close to sum, i.e., L relatively small. Achieved by using numbers that have overlapping prime factors, e.g., (2,3,6) where lcm = 6 = c. Sum = 11, ratio = 6/11. That's quite low.
#
# Could we get lower ratio with (3,4,12)? Let's test: lcm=12 sum=19 ratio = 12/19 ≈ 0.631. Not lower. (4,6,12) lcm=12 sum=22 ratio=12/22≈0.5454 equal to 6/11. Indeed same ratio because it's scaling of (2,3,6). So minimal ratio 6/11.
#
# Thus r(s) = min_{d|s, ...} Actually for s multiple of 11, we get ratio 6/11. For other s, ratio may be higher; for example for s multiple of 6 we have ratio 1 (since triple 1,2,3 scaled). But ratio 1 > 6/11. So minimal ratio across divisors of n is 6/11 if n has a divisor s that is multiple of 11. The minimal factor m = min_{s|n} r(s) will be 6/11 if n is divisible by some multiple of 11 (i.e., if 11|n). Because r(11) = 6/11, and also for any multiple of 11 we can have same ratio. So if n is divisible by 11, then f(n) = n * 6/11 = (6/11) n? Wait careful: For n divisible by 11, we can pick s = 11 (or any multiple). Then f(n) = n * (6/11) = (6n)/11, which must be integer? Since n multiple of 11, (6n)/11 integer.
#
# Thus f(n) = (6/11)n for n multiple of 11? Let's test with our brute list: n=11 we found f(11)=6. Indeed 6/11 * 11 = 6. Good. n=22 f(22)=12 (list shows 12). Indeed 6/11*22 = 12. n=33 f(33)=18 (list shows 18). n=44 f(44)=24 (list shows 24). n=55 f(55)=30 (list shows 30). Yes matches. So formula holds: f(n) = (6/11)n when 11|n.
#
# Now what about n not divisible by 11? We need min_{s|n} r(s). The minimal r(s) among divisors s of n maybe correspond to 6/11 if any divisor multiple of 11; else perhaps some other ratio. Let's compute for many n to see pattern: compute f(n)/n rational.
#
#
#
# [assistantanalysis to=python code]
# def f_brutal_fast(n):
#     # compute f(n) using earlier brute for small n
#     return f_brutal(n)[0]
#
# def f_by_divisor(n):
#     # compute using divisor approach with known r(s) from brute enumeration for s up to maybe 200?
#     # We'll compute r(s) for s up to 200 as before.
#     best = n+1
#     for s in sp.divisors(n):
#         if s<6: continue
#         r = r_vals.get(s, None)
#         # compute r(s) using brute if not precomputed
#         if r is None:
#             r,_ = best_triple_for_s(s)
#         candidate = int(n * r)  # n*r might be not integer but f(n) must be integer; compute L = (n/s)*lcm(x,y,z) = n * (lcm/s)
#         # Actually we need to compute exact L: L = n * (lcm/s)
#         # r = lcm/s rational maybe not integer; compute L rational.
#         # We'll compute directly: for each triple that gives minimal ratio, compute L = n * lcm/s = (n/s)*lcm.
#         # But we don't have that triple; maybe better to compute directly from s using best triple.
#         # So we compute best triple for s and compute L.
#         l,_ = best_triple_for_s(s)
#         L = (n // s) * math.lcm(*_)  # Wait we need best triple _ (a,b,c) sum s.
#
# [analysis]
# Let's compute f(n) using direct enumeration of divisor s and triple approach for small n to confirm formula.
#
#
#
# [assistantanalysis to=python code]
# def f_via_divisors(n):
#     best_L = None
#     best_trip = None
#     for s in sp.divisors(n):
#         if s<6:
#             continue
#         # get best triple for sum s
#         ratio,trip = best_triple_for_s(s)
#         a,b,c = trip
#         L = (n // s) * math.lcm(a,b,c)  # scaling factor n/s integer
#         # Actually scaling factor must be integer, n/s integer (by definition of divisor).
#         if best_L is None or L < best_L:
#             best_L = L
#             best_trip = (a,b,c,s)
#     return best_L,best_trip
#
# # test for n up to 100 compare with brute
# mismatch=[]
# for n in range(6,101):
#     f1 = f_brutal(n)[0]
#     f2,_ = f_via_divisors(n)
#     if f1!=f2:
#         mismatch.append((n,f1,f2))
# len(mismatch)
#
# [analysis]
# Great: the divisor approach works.
#
# Thus we have formula:
#
# $f(n) = \min_{s | n, s \ge 6} \frac{n}{s} \cdot L_s$, where $L_s$ is the minimal LCM for sum s.
#
# Given we found minimal ratio r(s) for s multiples of 11 is 6/11; for other s values ratio may be larger.
#
# Thus to compute f(n) we need to know minimal ratio across divisors of n. For huge n, its divisors include many small numbers like 6,7, etc? Actually n = M + c. M = 3^T, huge. Its divisors are powers of 3 up to M (including 1). Adding c will break the factorization. However M is a power of 3; adding c (small) will produce n with few small divisors; e.g., M+1 may be not divisible by 2 or 5; but it will be divisible by 3? M is divisible by 3, but M+1 is not. So n=M+1 is likely prime? Not necessarily but not divisible by 3.
#
# Thus for n = M + c, small divisors may be limited.
#
# Thus f(n) may be determined by the smallest divisor s of n such that r(s) is minimal. Since n huge, its small divisors likely only 1 and maybe some primes. But s must be at least 6, so we need small divisor >=6.
#
# Hence to compute f(M+c), we need to find divisors of M+c that are at least 6. Since M huge power of 3, M ≡ 0 (mod 3). For c values: 0, 4M, etc. Let's examine each:
#
# 1) c=0 => n = M. Since M is 3^T, divisible by many numbers (powers of 3). Its divisors are 3^k for k=0..T.
#
# Thus divisors s of M are powers of 3 only. So the smallest divisor ≥6 is 9? Actually 3^2=9 >6. 3^1=3 <6, 3^0=1. So smallest s≥6 is 9.
#
# Thus s=9 divides M.
#
# Now r(9) = we computed earlier ratio for s=9 is 2/3? Wait best triple for sum 9 is (1,2,6) LCM=6, ratio=6/9=2/3=0.666..., indeed r(9) = 2/3.
#
# But there might be other s divisors of M, like 27 with r(27) = 2/3 as scaling of (1,2,6). Let's verify r(27): minimal triple sum 27 maybe (3,6,18) scaling of (1,2,6) factor 3, LCM=6*3=18 ratio=18/27=2/3. So ratio remains 2/3.
#
# Thus for M (divisible by 9), the minimal ratio among its divisors might be r(9)=2/3. But wait, also s= 3^0=1,3,... can't use. So minimal ratio = 2/3.
#
# Thus f(M) = (2/3) * M = (2M)/3.
#
# But note, we need integer. Since M divisible by 3, (2M)/3 is integer: M = 3^T, M/3 = 3^{T-1}, thus f(M) = 2*3^{T-1} = 2 * 3^{T-1}.
#
# Thus f(M) = 2*3^{2025! - 1}. Let's denote.
#
# Now compute g(0) = (1/2025!) * floor(2025! * f(M) / M). f(M)/M = 2/3.
#
# Thus 2025! * f(M) / M = 2025! * (2/3) = (2/3) * 2025!. Since 2025! is divisible by 3? Yes because 2025! includes factor 3. So expression is integer: (2/3)*2025! = 2 * (2025!)/3 = integer.
#
# Now floor yields same integer. Then divide by 2025! gives g(0) = ((2/3) * 2025! )/2025! = 2/3.
#
# Thus g(0) = 2/3.
#
# Now compute g(4M): c = 4M, so n = M + 4M = 5M.
#
# Thus n = 5M = 5 * 3^T. n is multiple of M and factor 5.
#
# We need smallest divisor s of n (>=6) giving minimal ratio. Divisors of n are 5*3^k for k=0..T, and also powers 3^k (since 5*3^k also have divisors 3^j). So divisor set includes 5, 3,9,... Let's list small divisors >=6: 6? Actually 6 = 2*3, but 2 not a divisor of n because n's prime factors are only 3 and 5. So 6 does not divide. 9 divides (3^2). 10? 10 includes factor 2, not there. 12 includes factor 2, not there. 15 = 3*5 divides n (since n includes 3 and 5). So 15 divides n. 15 >=6. So divisors of n include 9, 15, 27, 45, etc. Also 5, but less than 6.
#
# Thus we can compute minimal r(s) among s dividing n.
#
# Let's compute r(9)=2/3 (as earlier). r(15) maybe? Let's compute best ratio for s=15. Use best triple function.
#
#
#
# [assistantanalysis to=python code]
# r15,trip15=best_triple_for_s(15)
# r15,trip15
#
# [analysis]
# r(15) = 0.8 > 2/3.
#
# r(27)=2/3. r(45)? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# best_triple_for_s(45)
#
# [analysis]
# r(45) = 2/3 as well (scaling of 1,2,6). Indeed 45 divisible by 9, ratio 2/3.
#
# Thus minimal r among divisors is 2/3 (since 9 divides n). Therefore f(n) = n * (2/3) = (2/3) * 5M = (10/3) M? Wait 5M * (2/3) = (10/3) M. But need integer. Since M = 3^T, (10/3) M = 10 * 3^{T-1}. That's integer.
#
# Thus f(5M) = (10/3)M = 10 * 3^{T-1}.
#
# Now compute g(4M) = (1/2025!) * floor(2025! * f(5M)/M) = (1/2025!)* floor(2025! * (10/3) )? Wait f(5M)/M = 10/3, since M cancels.
#
# Thus 2025! * (10/3) = (10/3) * 2025! = (10 * 2025!)/3 = (10/3)*2025!. Since 2025! divisible by 3, integer.
#
# So floor yields same integer.
#
# Thus g(4M) = ((10/3)*2025!)/2025! = 10/3.
#
# Thus g(4M) = 10/3.
#
# Now compute next terms: for c = 1848374 (a relatively small integer compared to M). So n = M + 1848374. We need to compute f(n). Since M is huge, n is not divisible by many small numbers, but maybe we can find small divisor s of n that yields small ratio.
#
# Since n = M + small constant, maybe n is prime or has small divisors like 2 or 3? Let's check mod small primes.
#
# M = 3^T. Since T is huge, M ≡ 0 mod 3.
#
# Thus n = M + c ≡ c (mod 3). So n mod 3 = c mod 3.
#
# Given c=1848374. Compute its mod 3: 1+8+4+8+3+7+4 = 35? Actually compute: 1+8+4+8+3+7+4 = 35, 35 mod 3 = 2. So c mod 3 = 2. Thus n ≡ 2 (mod 3). So n not divisible by 3.
#
# Check mod 2: c even? 1848374 is even, yes. M is odd (since power of 3). So n = odd+even = odd? Actually M is odd, even + odd => odd. So n is odd.
#
# Thus n is odd and not divisible by 3.
#
# Divisibility by 5? c mod 5 =? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# c=1848374
# c%5
#
# [analysis]
# Thus n ≡ 4 (mod 5). Since M mod 5 is 3^T mod 5; 3^phi(5)=3^4 ≡ 1 mod 5. T is huge factorial, divisible by 4? 2025! includes 4, so T is multiple of 4, thus 3^T ≡ 1 mod 5. So M ≡ 1 mod5. Then n ≡ 1+4=0 mod5 => n divisible by 5! Wait compute: M mod5 = 3^T mod5 = 3^{multiple of 4} ≡ (3^4)^{k} ≡ 1^k ≡ 1. So n mod5 = (1 + 4) = 0, so n divisible by 5. Good! So n has divisor 5 (>=6? Not; 5 is less than 6). So smallest divisor >=6 maybe? Could be 7? Let's test n mod7.
#
# Compute M mod7: Since 3^6 ≡ 1 mod7 (phi(7)=6). T = 2025! includes factor 6, so T multiple of 6 => M ≡ 1 mod7. Then n mod7 = 1 + c mod7.
#
# c=1848374 mod7? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# c%7
#
# [analysis]
# Thus n ≡ 1+3=4 mod7, not divisible by 7.
#
# Check divisibility by 11? M mod11: phi(11)=10, T includes 10 so M ≡ 1 mod11. c mod11? Compute.
#
#
#
# [assistantanalysis to=python code]
# c%11
#
# [analysis]
# c ≡ 0 mod11, thus n ≡ 1+0 = 1 mod11. Not divisible by 11.
#
# Thus n has small divisor 5 but that's <6. So we need smallest divisor s≥6. Could be 10? Since n is divisible by 5, but not necessarily by 2.
#
# But n is odd, so not divisible by 2. Hence any divisor multiple of 5 must be odd multiple of 5. Next candidate 15? Check if n divisible by 3? No. So not divisible by 15 (since 15 includes factor 3). Next candidate 25? 5^2 divides n? Need to check if n divisible by 25. M mod25? Since 3^20 ≡ 1 mod25 (phi=20). T includes factor 20, so M ≡ 1 mod25. c mod25? Compute.
#
#
#
# [assistantanalysis to=python code]
# c%25
#
# [analysis]
# Thus n ≡ 1+24=0 mod25! So n divisible by 25. Indeed n is divisible by 5^2. So s = 25 (>=6) divides n.
#
# Thus n has divisor s=25. What is r(25)? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# best_triple_for_s(25)
#
# [analysis]
# r(25) = 0.64 = 16/25.
#
# But we might have smaller ratio via other divisor s of n that yields r(s) = 6/11 if s multiple of 11, but n is not divisible by 11 as we saw. Maybe s=20? n odd cannot be divisible by 2. s=27? n not divisible by 3.
#
# Thus likely minimal ratio among divisors is something else.
#
# But also s could be 30? n odd no.
#
# Thus we need to compute minimal r(s) across all divisors s of n. Since n is huge, factoring n would be tough, but we may not need full factorization; we can consider small candidate s that are divisors of n based on congruences. Since n = M + c, and M ≡ 1 mod p for any p not dividing 3 (since 3^T ≡ 1 mod p when p-1 divides T? Actually by Euler's theorem: if p is prime not dividing 3, 3^{phi(p)} ≡ 1 mod p. Since T = 2025! is a multiple of phi(p) for all primes p <=2025 maybe, but not necessarily for all primes >2025. However T is huge, includes many numbers, but not all numbers? Actually phi(p) = p-1, which may be >2025 for large p. But T is 2025! which includes all numbers up to 2025, thus includes (p-1) if p-1 ≤2025, i.e., for primes p ≤2026. So for all primes up to 2025, we have 3^T ≡ 1 mod p. For larger primes, not guaranteed.
#
# But we only need divisors s up to maybe moderate size (like up to maybe few thousands) to evaluate minimal ratio. Since the minimal ratio we know is 6/11=~0.545. So we need to see if any divisor s of n is multiple of 11.
#
# Thus check if n is divisible by 11: we found n ≡ 1 mod11 not divisible.
#
# What about s=22? Must be even, not possible.
#
# What about s=33 (3*11). Since n not divisible by 3, not.
#
# Thus any multiple of 11 requires factor 11; n must be divisible by 11. Since n ≡ 1 mod11, not divisible. Therefore any divisor s containing factor 11 not possible (unless includes 11 and other primes where product is divisible by 11; but if n not divisible by 11, none of its divisors contain 11). So ratio 6/11 not achievable.
#
# Thus we need the best ratio from other s.
#
# Which s yields best (smallest) ratio? From earlier data: r(s) minimal among s not multiple of 11 appears to be maybe 2/3 (s multiple of 9) or 0.571 for s=7 (4/7) or 0.5714 for 14? Wait 4/7 ~0.571; 2/3=0.666. So 0.571 < 0.666. So better ratio is 4/7 for s=7,14,21,... Actually 21 is multiple of 7; but need divisors s.
#
# Thus maybe the best ratio among all s (>=6) is 4/7 = 0.571428..., which is attained by base triple (1,2,4) sum 7 lcm=4.
#
# Thus if n is divisible by 7, then we can achieve ratio 4/7 leading to f(n) = (4/7)n.
#
# Similarly maybe there is even better ratio like 5/9? Let's compute r(9) = 2/3 > 4/7. So 4/7 is currently minimal among computed values (besides 6/11). Let's test for s up to maybe 200 if any ratio smaller than 4/7 but not 6/11.
#
#
#
# [assistantanalysis to=python code]
# def min_ratio_excluding_11(limit):
#     best_ratio=1
#     best_s=None
#     best_trip=None
#     for s in range(6, limit+1):
#         if s%11==0:
#             continue
#         ratio,trip=best_triple_for_s(s)
#         if ratio<best_ratio:
#             best_ratio=ratio
#             best_s=s
#             best_trip=trip
#     return best_ratio,best_s,best_trip
#
# min_ratio_excluding_11(200)
#
# [analysis]
# Thus the minimal ratio apart from 6/11 is 4/7.
#
# Thus for any n divisible by 7 (i.e., includes factor 7), we can get f(n)= (4/7) n.
#
# Now does our n = M + 1848374 have divisor 7? n mod7 = (M mod7 + c mod7) = (1 + 3) = 4, not divisible. So 7 does not divide n.
#
# Next candidate ratio maybe 0.5454 (6/11) can't. Next candidate maybe ratio for s=13? r(13) approx .615 > .571.
#
# So minimal ratio for this n is possibly larger.
#
# But we can also consider divisor s=25 ratio 0.64 > .571. So best among divisors is maybe 0.64? Let's compute the set of small divisors of n (i.e., s dividing n). To compute we need factorization of n (M + 1848374). But n is huge; factoring may be impossible. However we can find small prime divisors by checking up to some bound. Since M is huge but we can compute n mod small primes using modular exponentiation.
#
# But we need only find small divisors s that give minimal ratio. Since r(s) decreasing as s increases? Not monotonic. We need to find minimal r(s) among all s dividing n. Since r(s) minimal values correspond to s = 7 (ratio 4/7) and s = 11 (6/11). Next maybe s = 13 ratio ~0.615 > 0.571. So the best ratio among small s (>=6) is either 6/11 (if 11|n) else 4/7 (if 7|n) else maybe 2/3 (if 9|n) else perhaps 0.6 (if 10|n) else 0.571 for 14 (if 14|n) but 14 contains factor 2; but n odd not divisible by 2.
#
# Thus for n odd, we can't have even divisor. So candidate s's are odd.
#
# Thus possible small odd s dividing n: 7 (ratio 4/7), 9 (2/3), 11 (6/11), 13 (~0.615), 15 (0.8) but 15 even? 15 odd yes ratio 0.8, 17 (~0.588), 19 (~0.632), 21 = 3*7 but 3 not dividing n (since n ≡ 2 mod3), so 21 can't divide. 23? ratio maybe around 0.608. 25 ratio 0.64. 27 ratio 0.666 (if 3 divides n, not). 29 ratio around 0.621. 31 maybe ratio ~0.645? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# def ratio_for_s(s):
#     ratio,_=best_triple_for_s(s)
#     return ratio
#
# # compute ratios for odd s up to 100
# ratios = {s: ratio_for_s(s) for s in range(7,101,2)}
# sorted_ratios = sorted(ratios.items(), key=lambda x: x[1])
# sorted_ratios[:15]
#
# [analysis]
# Thus ratios for odd s not divisible by 3 or 2 are either 0.571 for multiples of 7 (including 7 itself), 0.588 for multiples of 17, etc.
#
# Thus the best ratio among odd s not divisible by 3 is either 4/7 ≈ 0.571 (s multiple of 7) or 6/11 ≈ 0.545 if 11|n.
#
# Thus to compute f(M + c) for each c, we need to determine whether the number has divisor 11, 7, or maybe 9? Actually 9 divides if n divisible by 3 (since 9=3^2). So we need to test divisibility of n by small primes 3,5,7,11,13,17,...
#
# Since n = M + c and M ≡ 1 mod p for many primes (i.e., for primes p not dividing 3 and where exponent of 3's order modulo p divides T). But generally for any prime p not dividing 3, we have 3^{phi(p)} ≡ 1 mod p, where phi(p) = p-1. Since T = 2025! is divisible by (p-1) for all p up to 2025, but c values up to 265 million? Actually c up to 265,710,644; these are less than 2025! (which is astronomically huge). So for all primes p up to maybe 2 million (since 2 million < 2025!), p-1 <= 2 million < 2025!; thus T divisible by p-1, so 3^T ≡ 1 mod p. For primes greater than 2025, p-1 may exceed T, not guaranteed.
#
# But the c values are relatively small (< 3^something). So it's plausible that for all primes dividing n up to maybe a few million, M ≡ 1 mod p. So n ≡ 1 + c (mod p). So divisibility can be deduced via c ≡ -1 mod p.
#
# Thus we can compute small prime divisors of n by solving p divides (M + c) i.e., M ≡ -c (mod p). Since M ≡ 1 (mod p) for many p, then condition is 1 ≡ -c (mod p) => p divides c+1.
#
# Thus for any prime p (≤2025) where p does not divide 3, if p divides c+1, then p divides n. Similarly if p=3, M ≡0 mod3, so n ≡ c mod3.
#
# Thus to determine small prime divisors of n, we can compute primes p where p divides (c+1) (for p != 3). For p=3, we need c ≡ 0 mod3 for n divisible by 3.
#
# Thus for each c we can compute c+1's prime factorization (including possibly large primes). That will give us all small primes p (p ≤2025) dividing n.
#
# But n may have other prime divisors >2025 that divide n because M's order modulo them may not be 1; but we don't need to know them if we only need small divisor s (like 7,11). Since 7,11 ≤2025, we can deduce whether they divide n by checking whether (c+1) divisible by 7,11 respectively.
#
# Thus we can compute for each c.
#
# Specifically, for n = M + c, with M = 3^T, T = 2025!. For any prime p ≠ 3 with p ≤ 2025, we have M ≡ 1 (mod p). So n ≡ 1 + c (mod p). So p divides n iff p divides c+1.
#
# Thus to know if 7 divides n, test 7 | (c+1). If 11 divides n, test 11 | (c+1).
#
# Similarly for 9 (i.e., 3^2), we need n divisible by 9. Since M = 3^T is divisible by 9 (since T ≥2). n = M + c. Since M mod 9 = 0? Actually 3^T mod 9 = 0 if T≥2 (since 3^2=9). So M ≡ 0 (mod 9). Then n mod 9 = c mod 9.
#
# Thus n divisible by 9 iff c ≡ 0 (mod 9). Similarly, divisibility by 3: n divisible by 3 iff c ≡ 0 (mod 3) (since M ≡ 0 mod3). So we can compute for each c.
#
# Divisibility by 5: Since 5 ≤2025, prime not equal 3, M ≡ 1 (mod5). So n divisible by 5 iff 5|c+1. Indeed for c=1848374, c+1 = 1848375. Let's compute divisibility.
#
#
#
# [assistantanalysis to=python code]
# c=1848374
# c1=c+1
# divisible_by_5 = c1%5==0
# divisible_by_7 = c1%7==0
# divisible_by_11 = c1%11==0
# c1, divisible_by_5, divisible_by_7, divisible_by_11
#
# [analysis]
# Thus n divisible by 5 (but 5<6). Not by 7 or 11.
#
# Divisible by 9? c%9.
#
# [assistantanalysis to=python code]
# c%9
#
# [analysis]
# Thus n not divisible by 9.
#
# Divisible by 25? Need c+1 divisible by 25. c+1 = 1848375, 1848375/25 = 73935, so yes divisible by 25. So s=25 divides n.
#
# Thus minimal ratio may be from divisor s=25 (ratio 0.64). But could there be s=7*5=35 divides? Since 7 does not divide n, 35 not.
#
# What about s=13? Check c+1 %13.
#
#
#
# [assistantanalysis to=python code]
# c1%13
#
# [analysis]
# Thus not divisible.
#
# s=17? c+1%17?
#
#
#
# [assistantanalysis to=python code]
# c1%17
#
# [analysis]
# Thus not divisible.
#
# s=19? Let's compute.
#
#
#
# [assistantanalysis to=python code]
# c1%19
#
# [analysis]
# Thus not divisible.
#
# s=21 (3*7) can't because 7 not dividing.
#
# s=25 we have; ratio 0.64. Could there be s=27 (3^3) but n not divisible by 3.
#
# Thus minimal ratio is 0.64 maybe.
#
# ...
#                 # distinct automatically
#                 l=math.lcm(a,b,c)
#                 ratio=l/s
#                 if ratio<best:
#                     best=ratio
#         if best<math.inf:
#             r[s]=best
#     return r
#
# r_vals=compute_r(30)
# r_vals
#
#
# OUTPUT:
# {6: 1.0, 7: 0.5714285714285714, 8: 1.25, 9: 0.6666666666666666, 10: 0.6, 11: 0.5454545454545454, 12: 1.0, 13: 0.6153846153846154, 14: 0.5714285714285714, 15: 0.8, 16: 0.625, 17: 0.5882352941176471, 18: 0.6666666666666666, 19: 0.631578947368421, 20: 0.6, 21: 0.5714285714285714, 22: 0.5454545454545454, 23: 0.6086956521739131, 24: 1.0, 25: 0.64, 26: 0.6153846153846154, 27: 0.6666666666666666, 28: 0.5714285714285714, 29: 0.6206896551724138, 30: 0.6}
#
#
# ----------------------------------------
#
# [Python Call 10]
# CODE:
# def best_triple_for_s(s):
#     best_ratio=math.inf
#     best_trip=None
#     for a in range(1,s):
#         for b in range(a+1,s):
#             c=s-a-b
#             if c<=b:
#                 continue
#             l=math.lcm(a,b,c)
#             ratio=l/s
#             if ratio<best_ratio:
#                 best_ratio=ratio
#                 best_trip=(a,b,c)
#     return best_ratio,best_trip
#
# for s in range(6,101):
#     r,b=best_triple_for_s(s)
#     if r<0.55:
#         print(s, r,b)
#
#
# OUTPUT:
# 11 0.5454545454545454 (2, 3, 6)
# 22 0.5454545454545454 (4, 6, 12)
# 33 0.5454545454545454 (6, 9, 18)
# 44 0.5454545454545454 (8, 12, 24)
# 55 0.5454545454545454 (10, 15, 30)
# 66 0.5454545454545454 (12, 18, 36)
# 77 0.5454545454545454 (14, 21, 42)
# 88 0.5454545454545454 (16, 24, 48)
# 99 0.5454545454545454 (18, 27, 54)
#
#
# ----------------------------------------
#
# [Python Call 11]
# CODE:
# def compute_min_ratio(limit):
#     min_ratio = 1.0
#     min_s = None
#     best_trip=None
#     for s in range(6, limit+1):
#         ratio,trip=best_triple_for_s(s)
#         if ratio < min_ratio:
#             min_ratio=ratio
#             min_s=s
#             best_trip=trip
#     return min_ratio,min_s,best_trip
#
# compute_min_ratio(500)
#
#
# OUTPUT:
# (0.5454545454545454, 11, (2, 3, 6))
#
#
# ----------------------------------------
#
# [Python Call 12]
# CODE:
# def primitive_triples(limit):
#     mins = []
#     best_ratio=1
#     best_trip=None
#     for a in range(1,limit+1):
#         for b in range(a+1,limit+1):
#             for c in range(b+1,limit+1):
#                 if math.gcd(a, math.gcd(b,c)) != 1:
#                     continue
#                 # distinct positive integers, primitive
#                 s = a+b+c
#                 L = math.lcm(a,b,c)
#                 ratio=L/s
#                 if ratio < best_ratio:
#                     best_ratio=ratio
#                     best_trip=(a,b,c)
#     return best_ratio,best_trip
#
# primitive_triples(50)
#
#
# OUTPUT:
# (0.5454545454545454, (2, 3, 6))
#
#
# ----------------------------------------
#
# [Python Call 13]
# CODE:
# best_ratio,best_trip=primitive_triples(200)
# best_ratio,best_trip
#
#
# OUTPUT:
# 0.5454545454545454 (2, 3, 6)
#
#
# ----------------------------------------
#
# [Python Call 14]
# CODE:
# def f_brutal_fast(n):
#     # compute f(n) using earlier brute for small n
#     return f_brutal(n)[0]
#
# def f_by_divisor(n):
#     # compute using divisor approach with known r(s) from brute enumeration for s up to maybe 200?
#     # We'll compute r(s) for s up to 200 as before.
#     best = n+1
#     for s in sp.divisors(n):
#         if s<6: continue
#         r = r_vals.get(s, None)
#         # compute r(s) using brute if not precomputed
#         if r is None:
#             r,_ = best_triple_for_s(s)
#         candidate = int(n * r)  # n*r might be not integer but f(n) must be integer; compute L = (n/s)*lcm(x,y,z) = n * (lcm/s)
#         # Actually we need to compute exact L: L = n * (lcm/s)
#         # r = lcm/s rational maybe not integer; compute L rational.
#         # We'll compute directly: for each triple that gives minimal ratio, compute L = n * lcm/s = (n/s)*lcm.
#         # But we don't have that triple; maybe better to compute directly from s using best triple.
#         # So we compute best triple for s and compute L.
#         l,_ = best_triple_for_s(s)
#         L = (n // s) * math.lcm(*_)  # Wait we need best triple _ (a,b,c) sum s.
#
#
# OUTPUT:
#   File "/tmp/ipykernel_805/2943166777.py", line 22
#     print(L = (n // s) * math.lcm(*_)  # Wait we need best triple _ (a,b,c) sum s.)
#                                                                                    ^
# SyntaxError: incomplete input
#
#
# ----------------------------------------
#
# [Python Call 15]
# CODE:
# def f_via_divisors(n):
#     best_L = None
#     best_trip = None
#     for s in sp.divisors(n):
#         if s<6:
#             continue
#         # get best triple for sum s
#         ratio,trip = best_triple_for_s(s)
#         a,b,c = trip
#         L = (n // s) * math.lcm(a,b,c)  # scaling factor n/s integer
#         # Actually scaling factor must be integer, n/s integer (by definition of divisor).
#         if best_L is None or L < best_L:
#             best_L = L
#             best_trip = (a,b,c,s)
#     return best_L,best_trip
#
# # test for n up to 100 compare with brute
# mismatch=[]
# for n in range(6,101):
#     f1 = f_brutal(n)[0]
#     f2,_ = f_via_divisors(n)
#     if f1!=f2:
#         mismatch.append((n,f1,f2))
# len(mismatch)
#
#
# OUTPUT:
# 0
#
#
# ----------------------------------------
#
# [Python Call 16]
# CODE:
# r15,trip15=best_triple_for_s(15)
# r15,trip15
#
#
# OUTPUT:
# 0.8 (1, 2, 12)
#
#
# ----------------------------------------
#
# [Python Call 17]
# CODE:
# best_triple_for_s(45)
#
#
# OUTPUT:
# (0.6666666666666666, (5, 10, 30))
#
#
# ----------------------------------------
#
# [Python Call 18]
# CODE:
# c=1848374
# c%5
#
#
# OUTPUT:
# 4
#
#
# ----------------------------------------
#
# [Python Call 19]
# CODE:
# c%7
#
#
# OUTPUT:
# 3
#
#
# ----------------------------------------
#
# [Python Call 20]
# CODE:
# c%11
#
#
# OUTPUT:
# 0
#
#
# ----------------------------------------
#
# [Python Call 21]
# CODE:
# c%25
#
#
# OUTPUT:
# 24
#
#
# ----------------------------------------
#
# [Python Call 22]
# CODE:
# best_triple_for_s(25)
#
#
# OUTPUT:
# (0.64, (1, 8, 16))
#
#
# ----------------------------------------
#
# [Python Call 23]
# CODE:
# def min_ratio_excluding_11(limit):
#     best_ratio=1
#     best_s=None
#     best_trip=None
#     for s in range(6, limit+1):
#         if s%11==0:
#             continue
#         ratio,trip=best_triple_for_s(s)
#         if ratio<best_ratio:
#             best_ratio=ratio
#             best_s=s
#             best_trip=trip
#     return best_ratio,best_s,best_trip
#
# min_ratio_excluding_11(200)
#
#
# OUTPUT:
# (0.5714285714285714, 7, (1, 2, 4))
#
#
# ----------------------------------------
#
# [Python Call 24]
# CODE:
# def ratio_for_s(s):
#     ratio,_=best_triple_for_s(s)
#     return ratio
#
# # compute ratios for odd s up to 100
# ratios = {s: ratio_for_s(s) for s in range(7,101,2)}
# sorted_ratios = sorted(ratios.items(), key=lambda x: x[1])
# sorted_ratios[:15]
#
#
# OUTPUT:
# [(11, 0.5454545454545454), (33, 0.5454545454545454), (55, 0.5454545454545454), (77, 0.5454545454545454), (99, 0.5454545454545454), (7, 0.5714285714285714), (21, 0.5714285714285714), (35, 0.5714285714285714), (49, 0.5714285714285714), (63, 0.5714285714285714), (91, 0.5714285714285714), (17, 0.5882352941176471), (51, 0.5882352941176471), (85, 0.5882352941176471), (23, 0.6086956521739131)]
#
#
# ----------------------------------------
#
# [Python Call 25]
# CODE:
# c=1848374
# c1=c+1
# divisible_by_5 = c1%5==0
# divisible_by_7 = c1%7==0
# divisible_by_11 = c1%11==0
# c1, divisible_by_5, divisible_by_7, divisible_by_11
#
#
# OUTPUT:
# 1848375 True False False
#
#
# ----------------------------------------
#
# [Python Call 26]
# CODE:
# c%9
#
#
# OUTPUT:
# 8
#
#
# ----------------------------------------
#
# [Python Call 27]
# CODE:
# c1%13
#
#
# OUTPUT:
# 9
#
#
# ----------------------------------------
#
# [Python Call 28]
# CODE:
# c1%17
#
#
# OUTPUT:
# 16
#
#
# ----------------------------------------
#
# [Python Call 29]
# CODE:
# c1%19
#
#
# OUTPUT:
# 17
#
#
# ----------------------------------------
#
# [Python Call 30]
# CODE:
# cs = [10162574, 265710644, 44636594]
# def compute_ratio_for_c(c):
#     # Determine small divisor s that yields minimal ratio.
#     # Check divisibility by 11, 7, 25 (and 9 maybe), etc.
#     # We'll search for divisor s up to maybe 200 that divides n.
#     # We'll compute n_mod_s using modular exponent. But we know for s coprime to 3 and <=2025, n mod s = (c+1) mod s.
#     # For s containing factor 3 (i.e., multiple of 3), n mod s = c mod s.
#     # We'll search s up to maybe 200.
#     import sympy as sp
#     T = None
#     # we don't know M but we can compute n mod s via logic.
#     # define function n_mod_s(s):
#     def n_mod_s(s):
#         if s%3==0:
#             # M divisible by s? Not necessarily. M = 3^T, for s = 3^k (k<=T) it is divisible.
#             # For other s with factor 3 (e.g., 6, 12) M is not divisible by them but we can't rely on formula.
#             # However for s small with factor 3, we can compute directly: M = 0 mod 3^k, but not necessarily 0 mod other factors.
#             # This becomes messy, but we only care about s that are powers of 3 or multiples of 3 with maybe prime > 2025.
#             # For now we approximate: for s that are powers of 3, M mod s = 0.
#             # For s that have other prime factors besides 3, M mod s is not trivial.
#             # But we are likely to look at s = 9, 25, etc.
#             # We'll handle s=9,27 by checking c%9 etc.
#             if s in (9,27,81,243):
#                 return c % s  # since M% s =0
#             else:
#                 # Not needed for our s list
#                 return (0 + c) % s
#         else:
#             # M ≡ 1 mod s (since s <=2025? but we will only query small s)
#             return (1 + c) % s
#     # We'll compute best ratio among s dividing n
#     best_ratio = 1
#     best_s = None
#     for s in range(6,200):
#         if n_mod_s(s) == 0:
#             ratio,_ = best_triple_for_s(s)
#             if ratio < best_ratio:
#                 best_ratio = ratio
#                 best_s = s
#     return best_ratio,best_s
#
# for c in cs:
#     print(c, compute_ratio_for_c(c))
#
#
# OUTPUT:
# 10162574 (0.6382978723404256, 47)
# 265710644 (0.6597938144329897, 97)
# 44636594 (0.6586826347305389, 167)
#
#
# ----------------------------------------
#
# [Python Call 31]
# CODE:
# best_triple_for_s(47)
#
#
# OUTPUT:
# (0.6382978723404256, (2, 15, 30))
#
#
# ----------------------------------------
#
# [Python Call 32]
# CODE:
# c=10162574
# (c+1)%47
#
#
# OUTPUT:
# 0
#
#
# ----------------------------------------
#
# [Python Call 33]
# CODE:
# c=10162574
# (c+1)%7, (c+1)%11
#
#
# OUTPUT:
# 3 5
#
#
# ----------------------------------------
#
# [Python Call 34]
# CODE:
# c%9
#
#
# OUTPUT:
# 8
#
#
# ----------------------------------------
#
# [Python Call 35]
# CODE:
# c=10162574
# (c+1)%25
#
#
# OUTPUT:
# 0
#
#
# ----------------------------------------
#
# [Python Call 36]
# CODE:
# best_triple_for_s(97)
#
#
# OUTPUT:
# (0.6597938144329897, (1, 32, 64))
#
#
# ----------------------------------------
#
# [Python Call 37]
# CODE:
# c=265710644
# (c+1)%7, (c+1)%11
#
#
# OUTPUT:
# 4 2
#
#
# ----------------------------------------
#
# [Python Call 38]
# CODE:
# (c+1)%25
#
#
# OUTPUT:
# 20
#
#
# ----------------------------------------
#
# [Python Call 39]
# CODE:
# best_triple_for_s(167)
#
#
# OUTPUT:
# (0.6586826347305389, (2, 55, 110))
#
#
# ----------------------------------------
#
# [Python Call 40]
# CODE:
# from fractions import Fraction
# S = Fraction(2,3)+Fraction(10,3)+Fraction(16,25)+Fraction(30,47)+Fraction(64,97)+Fraction(110,167)
# S
#
#
# OUTPUT:
# 125561848/19033825
#
#
# ----------------------------------------
#
# [Python Call 41]
# CODE:
# import math
# math.gcd(125561848, 19033825)
#
#
# OUTPUT:
# 1
#
#
# ----------------------------------------
#
# [Python Call 42]
# CODE:
# p=125561848
# q=19033825
# (p+q)%99991
#
#
# OUTPUT:
# 8687
#
#
# ----------------------------------------
#
# [Python Call 43]
# CODE:
# def global_min_ratio(limit):
#     best_ratio=1
#     best_s=None
#     best_trip=None
#     for s in range(6, limit+1):
#         ratio,trip = best_triple_for_s(s)
#         if ratio<best_ratio:
#             best_ratio=ratio
#             best_s=s
#             best_trip=trip
#     return best_ratio, best_s, best_trip
#
# global_min_ratio(500)
#
#
# OUTPUT:
# (0.5454545454545454, 11, (2, 3, 6))
#
#
# ----------------------------------------
#
# [Python Call 44]
# CODE:
# global_min_ratio(5000)
#
#
# OUTPUT:
# [ERROR] Execution timed out after 6 seconds
#
# ----------------------------------------
#
# [Python Call 45]
# CODE:
# def find_best_ratio(limit):
#     best_ratio = 1
#     best_trip = None
#     for a in range(1, limit+1):
#         for b in range(a+1, limit+1):
#             for c in range(b+1, limit+1):
#                 # compute ratio
#                 l = math.lcm(a,b,c)
#                 ratio = l/(a+b+c)
#                 if ratio < best_ratio:
#                     best_ratio = ratio
#                     best_trip = (a,b,c)
#     return best_ratio,best_trip
#
# best_ratio,best_trip = find_best_ratio(100)
# best_ratio,best_trip
#
#
# OUTPUT:
# 0.5454545454545454 (2, 3, 6)
#
#
# ----------------------------------------
#
# [Python Call 46]
# CODE:
# best_ratio,best_trip = find_best_ratio(200)
# best_ratio,best_trip
#
#
# OUTPUT:
# 0.5454545454545454 (2, 3, 6)
#
#
# ----------------------------------------
#
# [Python Call 47]
# CODE:
# best_triple_for_s(31)
#
#
# OUTPUT:
# (0.6451612903225806, (1, 10, 20))
#
#
# ----------------------------------------
#
# [Python Call 48]
# CODE:
# 1848375%13
#
#
# OUTPUT:
# 9
#
#
# ----------------------------------------
#
# [Python Call 49]
# CODE:
# 1848375%17
#
#
# OUTPUT:
# 16
#
#
# ----------------------------------------
#
# [Python Call 50]
# CODE:
# 1848375%19
#
#
# OUTPUT:
# 17
#
#
# ----------------------------------------
#
# [Python Call 51]
# CODE:
# 1848375%23
#
#
# OUTPUT:
# 3
#
#
# ----------------------------------------
#
# [Python Call 52]
# CODE:
# 1848375%29
#
#
# OUTPUT:
# 2
#
#
# ----------------------------------------
#
# [Python Call 53]
# CODE:
# import sympy as sp
# c=10162574
# c1=c+1
# sp.factorint(c1)
#
#
# OUTPUT:
# {3: 2, 5: 2, 31: 2, 47: 1}
#
#
# ----------------------------------------
#
# [Python Call 54]
# CODE:
# c%3
#
#
# OUTPUT:
# 2
#
#
# ----------------------------------------
#
# [Python Call 55]
# CODE:
# c%25
#
#
# OUTPUT:
# 24
#
#
# ----------------------------------------
#
# [Python Call 56]
# CODE:
# c=265710644
# c1=c+1
# sp.factorint(c1)
#
#
# OUTPUT:
# {3: 3, 5: 1, 97: 1, 103: 1, 197: 1}
#
#
# ----------------------------------------
#
# [Python Call 57]
# CODE:
# c%3
#
#
# OUTPUT:
# 2
#
#
# ----------------------------------------
#
# [Python Call 58]
# CODE:
# best_triple_for_s(103)
#
#
# OUTPUT:
# (0.6601941747572816, (1, 34, 68))
#
#
# ----------------------------------------
#
# [Python Call 59]
# CODE:
# 68/103
#
#
# OUTPUT:
# 0.6601941747572816
#
#
# ----------------------------------------
#
# [Python Call 60]
# CODE:
# best_triple_for_s(197)
#
#
# OUTPUT:
# (0.6598984771573604, (2, 65, 130))
#
#
# ----------------------------------------
#
# [Python Call 61]
# CODE:
# 130/197
#
#
# OUTPUT:
# 0.6598984771573604
#
#
# ----------------------------------------
#
# [Python Call 62]
# CODE:
# c=44636594
# c1=c+1
# sp.factorint(c1)
#
#
# OUTPUT:
# {3: 1, 5: 1, 103: 1, 167: 1, 173: 1}
#
#
# ----------------------------------------
#
# [Python Call 63]
# CODE:
# best_triple_for_s(173)
#
#
# OUTPUT:
# (0.6589595375722543, (2, 57, 114))
#
#
# ----------------------------------------
#
# [Python Call 64]
# CODE:
# 114/173
#
#
# OUTPUT:
# 0.6589595375722543
#
#
# ----------------------------------------
#
# [Python Call 65]
# CODE:
# c=10162574
# c1=c+1
# c1%17
#
#
# OUTPUT:
# 9
#
#
# ----------------------------------------
#
# [Python Call 66]
# CODE:
# c=265710644
# c1=c+1
# c1%13
#
#
# OUTPUT:
# 5
#
#
# ----------------------------------------
#
# [Python Call 67]
# CODE:
# c1%17
#
#
# OUTPUT:
# 16
#
#
# ----------------------------------------
#
# [Python Call 68]
# CODE:
# c1%19
#
#
# OUTPUT:
# 15
#
#
# ----------------------------------------
#
# [Python Call 69]
# CODE:
# c1%23
#
#
# OUTPUT:
# 17
#
#
# ----------------------------------------
#
# [Python Call 70]
# CODE:
# c1%29
#
#
# OUTPUT:
# 1
#
#
# ----------------------------------------
#
# [Python Call 71]
# CODE:
# c=44636594
# (c+1)%13
#
#
# OUTPUT:
# 3
#
#
# ----------------------------------------
#
# [Python Call 72]
# CODE:
# (c+1)%17
#
#
# OUTPUT:
# 1
#
#
# ----------------------------------------
#
# [Python Call 73]
# CODE:
# (c+1)%19
#
#
# OUTPUT:
# 9
#
#
# ----------------------------------------
#
# [Python Call 74]
# CODE:
# (c+1)%23
#
#
# OUTPUT:
# 12
#
#
# ----------------------------------------
#
# [Python Call 75]
# CODE:
# (c+1)%29
#
#
# OUTPUT:
# 27
#
#
# ----------------------------------------
#
# [Python Call 76]
# CODE:
# from fractions import Fraction
# S = Fraction(4,1) + Fraction(16,25) + Fraction(30,47) + Fraction(64,97) + Fraction(110,167)
# p=S.numerator
# q=S.denominator
# (p+q)%99991
#
#
# OUTPUT:
# 8687
#
#
# ----------------------------------------
#
#
# Final Answer: 41754
